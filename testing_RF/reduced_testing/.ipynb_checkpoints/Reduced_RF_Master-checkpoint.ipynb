# %% [markdown]
# ### Random Forests at 14-days leadtime for all regions.
#
# File generated 9/18/2025 for Chapter 4 of Dissertation.
# Modified 12/8/2025 for use in reduced UFS analysis.
#
# This file utilizes definition statements containing RF architecture to create three separate RF models, each for a designated forecast region.
#
# Forecast leadtime can be changed as needed.

# %%
##just to stop the excess number of warnings 
import warnings
warnings.filterwarnings('ignore')

#relevant import statements
import numpy as np
import math
import pandas as pd
import xarray as xr 
import pickle 
import matplotlib.pyplot as plt

import random
from random import seed
from random import randint
from random import sample

import seaborn as sns # statistical data visualization
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.feature_selection import SelectFromModel

import keras
import shap
# Out:
# 2026-02-03 15:13:06.282282: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-03 15:13:06.329653: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-02-03 15:13:06.329690: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-02-03 15:13:06.330967: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-02-03 15:13:06.338450: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-03 15:13:09.254984: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#import definitions 
from SkillStats_MOD import BSS, RAS, PAS

from RF_archMOD import rf_featselect,rf_90thpercentile

# %% [markdown]
# I am going to do a modified version of the architecture def here because I have to change the dataset structure.
#
# Start with bringing in the old data for training/validation.

# %%
#load OG input data, it is max/min standardized, NaNs removed
#stratospheric polar vortex ellipse diagnostics from Fernandez et al 2025 (in review)
infile = open("../old_data/nolag_extendedanom_SEPARATED.p", 'rb') 
nolag_input = pickle.load(infile)
infile.close()

nolag_input.shape
# Out:
# (62, 149, 8)

# %% [markdown]
# The input data stays the same regardless of forecast region.
#
# The original array starts on October 19th. The shift send this forward to November 2nd.

# %%
idx = 135 #129 for 20, 119 for 30.
inp1 = np.empty((52,idx,7)) #cnew input array, 14 day lag. 
shift = 14

##reshaping to change lag in metrics for input
inp1[:,:,0] = nolag_input[:52,shift:,0] ##wind
inp1[:,:,1] = nolag_input[:52,shift:,1] ##ratio
inp1[:,:,2] = nolag_input[:52,shift:,2] ##latitude
inp1[:,:,3] = nolag_input[:52,shift:,3] ##longitude
inp1[:,:,4] = nolag_input[:52,shift:,4] ##size
inp1[:,:,5] = nolag_input[:52,shift:,5] ##ephi
inp1[:,:,6] = nolag_input[:52,shift:,6] ##gph

inp = inp1.reshape(52*idx,7)

#convert to pandas dataframe
input1 = pd.DataFrame(inp)
#label columns of variables for input data
col_names = ['wind','rat','cenlat','cenlon','size','ephi','gph']
input1.columns = col_names

# %%
def testing_data(p):
    infile = open(f'./new_data/input_{str(p)}.p', 'rb') 
    testing_input = pickle.load(infile)
    infile.close()
    
    inp = testing_input.reshape(56*10,7)
    
    #convert to pandas dataframe
    input2 = pd.DataFrame(inp)
    #label columns of variables for input data
    col_names = ['wind','rat','cenlat','cenlon','size','ephi','gph']
    input2.columns = col_names
    return input2

# %% [markdown]
# ### Begin RF Feature selection test.

# %%
def feat_imp_plot(important,input1,files,prototype):
    imp = np.nanmean(important, axis = 0)
    imp.shape
    
    #plot features by relative importance
    indices = np.argsort(imp)[::-1]  #sort by importance
    c = ["navy","royalblue","slateblue","blueviolet","darkviolet","purple","mediumvioletred","magenta"]
    
    plt.figure(figsize=(9, 6))
    plt.title(f'Average Feature Importances Across 100 CVs, {str(files)}',fontsize =18)
    plt.barh(range(input1.shape[1]), imp[indices], align="center", color = c)
    plt.yticks(range(input1.shape[1]), input1.columns[indices],fontsize =14)
    plt.xticks(fontsize =14)
    plt.xlabel("Relative Importance",fontsize =16)
    plt.gca().invert_yaxis()
    plt.savefig(f'./images/{str(prototype)}/FeatureImportance_{str(files)}.png',bbox_inches = 'tight')
    plt.close()

# %%
def SHAP_imp_plot(shap_obj, files, prototype):
    plt.title("SHAP Values for Negative Temp Anomalies",fontsize =14, y = 1.05)
    ax = shap.plots.beeswarm(shap_obj[:,:,0], show = False) ##for negative classifications ... this is physically consistent!
    #ax.set_xlim(-0.3,0.3)  
    plt.savefig(f'./images/{str(prototype)}/SHAP_FeatureImportance_{str(files)}.png',bbox_inches = 'tight')
    plt.close()

# %%
#number of cross validations
n = 100

regions = ['eur','nova','seus']

#list for top 90%?
eur_feats = []
nova_feats = []
seus_feats = []

# %%
##Loop through regions and files to do feature selection.
for i in range(len(regions)):
    ##EUROPE
    if regions[i] == 'eur':
        files = ['Europe_ERA5','Europe_Prototype5','Europe_Prototype6','Europe_Prototype7','Europe_Prototype8']
        prototype = ['ERA5','Prototype5','Prototype6','Prototype7','Prototype8']
        for j in range(len(files)):
            print(f'Working on {str(files[j])} ...')
            input2 = testing_data(prototype[j])
            eur_important, eur_top90_idx, eur_shap_obj = rf_featselect(n,shift,idx,input1,input2,regions[i],files[j])
            ##OG Feature Importance
            feat_imp_plot(eur_important,input1,files[j], prototype[j])
            ##SHAP Feature Importance
            SHAP_imp_plot(eur_shap_obj,files[j], prototype[j])
            #Save top 90% to list
            eur_feats.append(eur_top90_idx)
            print('_____________________________________')
            
    ##CANADA
    if regions[i] == 'nova':
        files = ['Canada_ERA5','Canada_Prototype5','Canada_Prototype6','Canada_Prototype7','Canada_Prototype8']
        prototype = ['ERA5','Prototype5','Prototype6','Prototype7','Prototype8']
        for j in range(len(files)):
            print(f'Working on {str(files[j])} ...')
            input2 = testing_data(prototype[j])
            can_important, can_top90_idx, can_shap_obj  = rf_featselect(n,shift,idx,input1,input2,regions[i],files[j])
            ##OG Feature Importance
            feat_imp_plot(can_important,input1, files[j], prototype[j])
            ##SHAP Feature Importance
            SHAP_imp_plot(can_shap_obj, files[j], prototype[j])
            #Save top 90% to list
            nova_feats.append(can_top90_idx)
            print('_____________________________________')
            
    ##SEUS
    if regions[i] == 'seus':
        files = ['SEUS_ERA5','SEUS_Prototype5','SEUS_Prototype6','SEUS_Prototype7','SEUS_Prototype8']
        prototype = ['ERA5','Prototype5','Prototype6','Prototype7','Prototype8']
        for j in range(len(files)):
            print(f'Working on {str(files[j])} ...')
            input2 = testing_data(prototype[j])
            seus_important, seus_top90_idx, seus_shap_obj = rf_featselect(n,shift,idx,input1,input2,regions[i],files[j])
            ##OG Feature Importance
            feat_imp_plot(seus_important,input1, files[j], prototype[j])
            ##SHAP Feature Importance
            SHAP_imp_plot(seus_shap_obj, files[j], prototype[j])
            #Save top 90% to list
            seus_feats.append(seus_top90_idx)
            print('_____________________________________')
# Out:
# Working on Europe_ERA5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 58.24%
# Accuracy, Training: 63.11%
# Accuracy, Testing: 64.35%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 6 features explain 90% of total SHAP importance
# _____________________________________
# Working on Europe_Prototype5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 58.27%
# Accuracy, Training: 63.15%
# Accuracy, Testing: 68.10%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 6 features explain 90% of total SHAP importance
# _____________________________________
# Working on Europe_Prototype6 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 58.00%
# Accuracy, Training: 63.17%
# Accuracy, Testing: 60.91%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 6 features explain 90% of total SHAP importance
# _____________________________________
# Working on Europe_Prototype7 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 57.89%
# Accuracy, Training: 63.17%
# Accuracy, Testing: 57.19%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 6 features explain 90% of total SHAP importance
# _____________________________________
# Working on Europe_Prototype8 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 58.38%
# Accuracy, Training: 63.12%
# Accuracy, Testing: 55.97%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 6 features explain 90% of total SHAP importance
# _____________________________________
# Working on Canada_ERA5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 71.28%
# Accuracy, Training: 72.06%
# Accuracy, Testing: 75.13%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 4 features explain 90% of total SHAP importance
# _____________________________________
# Working on Canada_Prototype5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 71.39%
# Accuracy, Training: 72.03%
# Accuracy, Testing: 66.33%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 4 features explain 90% of total SHAP importance
# _____________________________________
# Working on Canada_Prototype6 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 70.59%
# Accuracy, Training: 72.27%
# Accuracy, Testing: 72.61%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 4 features explain 90% of total SHAP importance
# _____________________________________
# Working on Canada_Prototype7 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 71.53%
# Accuracy, Training: 72.02%
# Accuracy, Testing: 70.92%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 4 features explain 90% of total SHAP importance
# _____________________________________
# Working on Canada_Prototype8 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 71.12%
# Accuracy, Training: 72.10%
# Accuracy, Testing: 67.69%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 4 features explain 90% of total SHAP importance
# _____________________________________
# Working on SEUS_ERA5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 62.19%
# Accuracy, Training: 63.22%
# Accuracy, Testing: 58.96%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 5 features explain 90% of total SHAP importance
# _____________________________________
# Working on SEUS_Prototype5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 62.31%
# Accuracy, Training: 63.14%
# Accuracy, Testing: 58.26%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 5 features explain 90% of total SHAP importance
# _____________________________________
# Working on SEUS_Prototype6 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 62.33%
# Accuracy, Training: 63.16%
# Accuracy, Testing: 61.79%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 5 features explain 90% of total SHAP importance
# _____________________________________
# Working on SEUS_Prototype7 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 62.28%
# Accuracy, Training: 63.15%
# Accuracy, Testing: 60.20%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 5 features explain 90% of total SHAP importance
# _____________________________________
# Working on SEUS_Prototype8 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 62.13%
# Accuracy, Training: 63.19%
# Accuracy, Testing: 55.09%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 5 features explain 90% of total SHAP importance
# _____________________________________

# %% [markdown]
# ## Second RF run post feature selection

# %% [markdown]
# ### Europe

# %%
##Loop through regions and files to do feature selection.
prototype = ['ERA5','Prototype5','Prototype6','Prototype7','Prototype8']
####################
files = ['Europe_ERA5','Europe_Prototype5','Europe_Prototype6','Europe_Prototype7','Europe_Prototype8']

for j in range(len(files)):
    print(f'Working on {str(files[j])} ...')
    ##select prototype testing data ...
    input2 = testing_data(prototype[j])
    
    eur_input1 = input1[input1.columns[eur_feats[j]]]
    eur_input2 = input2[input2.columns[eur_feats[j]]]
  
    ##CONSTANT ERA5 OUTPUT
    infile = open(f'./new_data/2classtemps_Europe_ERA5.p',"rb",)
    ERA5_temp = pickle.load(infile) 
    infile.close()

    eur_test90, eur_fulltest, eur_shap_obj, eur_posXtest, eur_FposXtest, eur_negXtest, eur_FnegXtest, acc_reg2_test, acc_reg3_test, acc_reg4_test = rf_90thpercentile(n,shift, idx, eur_input1, eur_input2, ERA5_temp, 'eur', files[j])
    #____________________________________________________#
    #plot SHAP
    plt.title(f'SHAP Values for Negative Europe Temp Anomalies, {str(files[j])}',fontsize =14, y = 1.05)
    ax = shap.plots.beeswarm(eur_shap_obj[:,:,0], show = False) ##for negative classifications ... this is physically consistent!
    plt.tight_layout()
    plt.savefig(f'./images/{str(prototype[j])}/SHAP_{str(files[j])}.png')
    plt.close()
    #____________________________________________________#
    #plot ACC
    bins = np.linspace(0.4, 1,13)  # 10 bins from 0.4 to 1
    ##bin the testing 90th percentile accuracy data
    counts90, edges90 = np.histogram(eur_test90, bins=bins)
    countsfull, edgesfull = np.histogram(eur_fulltest, bins=bins)
    counts_era5, edges_era5= np.histogram(acc_reg3_test, bins=bins) ##relative to ERA5 truth
    #plot the full dataset
    #offset = 0.02  # Adjust this value if needed for better visibility
    plt.bar(edgesfull[:-1], countsfull, width=np.diff(edgesfull), 
            edgecolor='black', alpha=0.5, label='All Predictions', align='edge', color='blue')
    
    #plot the 90th percentile
    plt.bar(edges90[:-1], counts90, width=np.diff(edges90), 
            edgecolor='black', alpha=0.5, label='>90th Percentile Predictions', align='edge', color = 'lightblue')
    
    #plot the ERA-5 comparison
    plt.bar(edges_era5[:-1], counts_era5, width=np.diff(edges_era5), 
            edgecolor='black', alpha=0.5, label='Predictions vs. ERA-5 Truth', align='edge', color = 'indigo')
    
    plt.xlabel('Accuracy',fontsize =14)
    plt.ylabel('Number of Models',fontsize =14)
    plt.ylim(0,105)
    plt.legend()
    plt.title(f'Testing ACCs for 100 CVs, {str(files[j])}',fontsize =12)
    plt.tight_layout()
    plt.savefig(f'./images/{str(prototype[j])}/ACC_{str(files[j])}.png')
    plt.close()
    print('_____________________________________')
    #____________________________________________________#
    ##export out files to make the next few plots w/o normalization
    pickle.dump(eur_posXtest, open(f'./index/pos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FposXtest, open(f'./index/Fpos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_negXtest, open(f'./index/neg_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FnegXtest, open(f'./index/Fneg_{str(files[j])}.p', 'wb'))
# Out:
# Working on Europe_ERA5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 58.07%
# Accuracy, Training: 62.58%
# Accuracy, Testing: 62.32%
# ###################################################
# Brier Skill Score (Test): 0.0614
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.6917
# Precision Accuracy Score (Test): 0.6017
# F1 Score (Test): 0.6419
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5572
# Precision Accuracy Score (Train): 0.6466
# F1 Score (Test): 0.5997
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 39.66%
# Average Num. of 10% Confident and Correct Negative Predictions: 38.90%
# Average Num. of 10% Confident and FALSE Postive Predictions: 10.30%
# Average Num. of 10% Confident and FALSE Negative Predictions: 11.14%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 78.56%
# Average Num. of 10% Confident and FALSE Predictions: 21.44%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Europe_Prototype5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 58.07%
# Accuracy, Training: 62.68%
# Accuracy, Testing: 67.32%
# ###################################################
# Brier Skill Score (Test): 0.0880
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.8014
# Precision Accuracy Score (Test): 0.6103
# F1 Score (Test): 0.6919
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5645
# Precision Accuracy Score (Train): 0.6468
# F1 Score (Test): 0.6506
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 47.25%
# Average Num. of 10% Confident and Correct Negative Predictions: 38.90%
# Average Num. of 10% Confident and FALSE Postive Predictions: 2.74%
# Average Num. of 10% Confident and FALSE Negative Predictions: 11.11%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 86.15%
# Average Num. of 10% Confident and FALSE Predictions: 13.85%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Europe_Prototype6 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 58.47%
# Accuracy, Training: 62.51%
# Accuracy, Testing: 60.68%
# ###################################################
# Brier Skill Score (Test): 0.0543
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.7033
# Precision Accuracy Score (Test): 0.5728
# F1 Score (Test): 0.6296
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5190
# Precision Accuracy Score (Train): 0.6449
# F1 Score (Test): 0.5778
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 42.54%
# Average Num. of 10% Confident and Correct Negative Predictions: 34.28%
# Average Num. of 10% Confident and FALSE Postive Predictions: 7.43%
# Average Num. of 10% Confident and FALSE Negative Predictions: 15.74%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 76.82%
# Average Num. of 10% Confident and FALSE Predictions: 23.18%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Europe_Prototype7 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 57.90%
# Accuracy, Training: 62.56%
# Accuracy, Testing: 56.96%
# ###################################################
# Brier Skill Score (Test): 0.0134
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.6374
# Precision Accuracy Score (Test): 0.5501
# F1 Score (Test): 0.5883
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5056
# Precision Accuracy Score (Train): 0.6469
# F1 Score (Test): 0.5448
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 30.80%
# Average Num. of 10% Confident and Correct Negative Predictions: 23.55%
# Average Num. of 10% Confident and FALSE Postive Predictions: 19.16%
# Average Num. of 10% Confident and FALSE Negative Predictions: 26.49%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 54.35%
# Average Num. of 10% Confident and FALSE Predictions: 45.65%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Europe_Prototype8 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 57.76%
# Accuracy, Training: 62.65%
# Accuracy, Testing: 57.36%
# ###################################################
# Brier Skill Score (Test): 0.0360
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.6214
# Precision Accuracy Score (Test): 0.5764
# F1 Score (Test): 0.5964
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5237
# Precision Accuracy Score (Train): 0.6468
# F1 Score (Test): 0.5448
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 39.21%
# Average Num. of 10% Confident and Correct Negative Predictions: 32.40%
# Average Num. of 10% Confident and FALSE Postive Predictions: 10.76%
# Average Num. of 10% Confident and FALSE Negative Predictions: 17.63%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 71.61%
# Average Num. of 10% Confident and FALSE Predictions: 28.39%
#
#
# Trying SHAP ...
# Done.
# _____________________________________

# %% [markdown]
# ### Canada

# %%
##Loop through regions and files to do feature selection.
files = ['Canada_ERA5','Canada_Prototype5','Canada_Prototype6','Canada_Prototype7','Canada_Prototype8']

for j in range(len(files)):
    print(f'Working on {str(files[j])} ...')

    input2 = testing_data(prototype[j])
    eur_input1 = input1[input1.columns[nova_feats[j]]]
    eur_input2 = input2[input2.columns[nova_feats[j]]]

    ##CONSTANT ERA5 OUTPUT
    infile = open(f'./new_data/2classtemps_Canada_ERA5.p',"rb",)
    ERA5_temp = pickle.load(infile) 
    infile.close()
    
    eur_test90, eur_fulltest, eur_shap_obj, eur_posXtest, eur_FposXtest, eur_negXtest, eur_FnegXtest, acc_reg2_test, acc_reg3_test, acc_reg4_test = rf_90thpercentile(n,shift, idx, eur_input1, eur_input2, ERA5_temp, 'nova',files[j])
    #____________________________________________________#
    #plot SHAP
    plt.title(f'SHAP Values for Negative Canadian Temp Anomalies, {str(files[j])}',fontsize =14, y = 1.05)
    ax = shap.plots.beeswarm(eur_shap_obj[:,:,0], show = False) ##for negative classifications ... this is physically consistent!
    plt.tight_layout()
    plt.savefig(f'./images/{str(prototype[j])}/SHAP_{str(files[j])}.png')
    plt.close()
    #____________________________________________________#
    #plot ACC
    bins = np.linspace(0.4, 1,13)  # 10 bins from 0.4 to 1
    ##bin the testing 90th percentile accuracy data
    counts90, edges90 = np.histogram(eur_test90, bins=bins)
    countsfull, edgesfull = np.histogram(eur_fulltest, bins=bins)
    counts_era5, edges_era5= np.histogram(acc_reg3_test, bins=bins) ##relative to ERA5 truth
    #plot the full dataset
    #offset = 0.02  # Adjust this value if needed for better visibility
    plt.bar(edgesfull[:-1], countsfull, width=np.diff(edgesfull), 
            edgecolor='black', alpha=0.5, label='All Predictions', align='edge', color='blue')
    
    #plot the 90th percentile
    plt.bar(edges90[:-1], counts90, width=np.diff(edges90), 
            edgecolor='black', alpha=0.5, label='>90th Percentile Predictions', align='edge', color = 'lightblue')
    
    #plot the ERA-5 comparison
    plt.bar(edges_era5[:-1], counts_era5, width=np.diff(edges_era5), 
            edgecolor='black', alpha=0.5, label='Predictions vs. ERA-5 Truth', align='edge', color = 'indigo')
    
    plt.xlabel('Accuracy',fontsize =14)
    plt.ylabel('Number of Models',fontsize =14)
    plt.ylim(0,105)
    plt.legend()
    plt.title(f'Testing ACCs for 100 CVs, {str(files[j])}',fontsize =12)
    plt.tight_layout()
    plt.savefig(f'./images/{str(prototype[j])}/ACC_{str(files[j])}.png')
    plt.close()
    print('_____________________________________')
    #____________________________________________________#
    ##export out files to make the next few plots w/o normalization
    pickle.dump(eur_posXtest, open(f'./index/pos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FposXtest, open(f'./index/Fpos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_negXtest, open(f'./index/neg_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FnegXtest, open(f'./index/Fneg_{str(files[j])}.p', 'wb'))
# Out:
# Working on Canada_ERA5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 70.79%
# Accuracy, Training: 72.09%
# Accuracy, Testing: 76.46%
# ###################################################
# Brier Skill Score (Test): 0.2201
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.8896
# Precision Accuracy Score (Test): 0.7603
# F1 Score (Test): 0.8194
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5758
# Precision Accuracy Score (Train): 0.7691
# F1 Score (Test): 0.6610
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 44.62%
# Average Num. of 10% Confident and Correct Negative Predictions: 30.70%
# Average Num. of 10% Confident and FALSE Postive Predictions: 5.36%
# Average Num. of 10% Confident and FALSE Negative Predictions: 19.32%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 75.32%
# Average Num. of 10% Confident and FALSE Predictions: 24.68%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Canada_Prototype5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 71.42%
# Accuracy, Training: 71.94%
# Accuracy, Testing: 66.91%
# ###################################################
# Brier Skill Score (Test): 0.1239
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.8754
# Precision Accuracy Score (Test): 0.6175
# F1 Score (Test): 0.7238
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.4657
# Precision Accuracy Score (Train): 0.7685
# F1 Score (Test): 0.5862
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 46.57%
# Average Num. of 10% Confident and Correct Negative Predictions: 33.68%
# Average Num. of 10% Confident and FALSE Postive Predictions: 3.46%
# Average Num. of 10% Confident and FALSE Negative Predictions: 16.29%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 80.25%
# Average Num. of 10% Confident and FALSE Predictions: 19.75%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Canada_Prototype6 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 70.87%
# Accuracy, Training: 72.04%
# Accuracy, Testing: 73.84%
# ###################################################
# Brier Skill Score (Test): 0.2174
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.9032
# Precision Accuracy Score (Test): 0.7080
# F1 Score (Test): 0.7934
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5312
# Precision Accuracy Score (Train): 0.7685
# F1 Score (Test): 0.6427
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 47.50%
# Average Num. of 10% Confident and Correct Negative Predictions: 38.89%
# Average Num. of 10% Confident and FALSE Postive Predictions: 2.50%
# Average Num. of 10% Confident and FALSE Negative Predictions: 11.11%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 86.39%
# Average Num. of 10% Confident and FALSE Predictions: 13.61%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Canada_Prototype7 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 70.68%
# Accuracy, Training: 72.07%
# Accuracy, Testing: 71.40%
# ###################################################
# Brier Skill Score (Test): 0.1868
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.9035
# Precision Accuracy Score (Test): 0.6562
# F1 Score (Test): 0.7598
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5231
# Precision Accuracy Score (Train): 0.7688
# F1 Score (Test): 0.6456
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 48.26%
# Average Num. of 10% Confident and Correct Negative Predictions: 40.45%
# Average Num. of 10% Confident and FALSE Postive Predictions: 1.76%
# Average Num. of 10% Confident and FALSE Negative Predictions: 9.53%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 88.70%
# Average Num. of 10% Confident and FALSE Predictions: 11.30%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Canada_Prototype8 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 70.93%
# Accuracy, Training: 72.02%
# Accuracy, Testing: 67.66%
# ###################################################
# Brier Skill Score (Test): 0.1686
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.8515
# Precision Accuracy Score (Test): 0.6467
# F1 Score (Test): 0.7347
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.4818
# Precision Accuracy Score (Train): 0.7686
# F1 Score (Test): 0.5845
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 43.92%
# Average Num. of 10% Confident and Correct Negative Predictions: 46.02%
# Average Num. of 10% Confident and FALSE Postive Predictions: 6.09%
# Average Num. of 10% Confident and FALSE Negative Predictions: 3.97%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 89.94%
# Average Num. of 10% Confident and FALSE Predictions: 10.06%
#
#
# Trying SHAP ...
# Done.
# _____________________________________

# %% [markdown]
# ### SEUS

# %%
##Loop through regions and files to do feature selection.
files = ['SEUS_ERA5','SEUS_Prototype5','SEUS_Prototype6','SEUS_Prototype7','SEUS_Prototype8']

for j in range(len(files)):
    print(f'Working on {str(files[j])} ...')
    
    input2 = testing_data(prototype[j])
    eur_input1 = input1[input1.columns[seus_feats[j]]]
    eur_input2 = input2[input2.columns[seus_feats[j]]]

    ##CONSTANT ERA5 OUTPUT
    infile = open(f'./new_data/2classtemps_SEUS_ERA5.p',"rb",)
    ERA5_temp = pickle.load(infile) 
    infile.close()
    
    eur_test90, eur_fulltest, eur_shap_obj, eur_posXtest, eur_FposXtest, eur_negXtest, eur_FnegXtest, acc_reg2_test, acc_reg3_test, acc_reg4_test = rf_90thpercentile(n,shift, idx, eur_input1, eur_input2, ERA5_temp, 'seus', files[j])
    #____________________________________________________#
    #plot SHAP
    plt.title(f'SHAP Values for SEUS Temp Anomalies, {str(files[j])}',fontsize =14, y = 1.05)
    ax = shap.plots.beeswarm(eur_shap_obj[:,:,0], show = False) ##for negative classifications ... this is physically consistent!
    plt.tight_layout()
    plt.savefig(f'./images/{str(prototype[j])}/SHAP_{str(files[j])}.png')
    plt.close()
    #____________________________________________________#
    #plot ACC
    bins = np.linspace(0.4, 1,13)  # 10 bins from 0.4 to 1
    ##bin the testing 90th percentile accuracy data
    counts90, edges90 = np.histogram(eur_test90, bins=bins)
    countsfull, edgesfull = np.histogram(eur_fulltest, bins=bins)
    counts_era5, edges_era5= np.histogram(acc_reg3_test, bins=bins) ##relative to ERA5 truth
    #plot the full dataset
    #offset = 0.02  # Adjust this value if needed for better visibility
    plt.bar(edgesfull[:-1], countsfull, width=np.diff(edgesfull), 
            edgecolor='black', alpha=0.5, label='All Predictions', align='edge', color='blue')
    
    #plot the 90th percentile
    plt.bar(edges90[:-1], counts90, width=np.diff(edges90), 
            edgecolor='black', alpha=0.5, label='>90th Percentile Predictions', align='edge', color = 'lightblue')
    
    #plot the ERA-5 comparison
    plt.bar(edges_era5[:-1], counts_era5, width=np.diff(edges_era5), 
            edgecolor='black', alpha=0.5, label='Predictions vs. ERA-5 Truth', align='edge', color = 'indigo')
    
    plt.xlabel('Accuracy',fontsize =14)
    plt.ylabel('Number of Models',fontsize =14)
    plt.ylim(0,105)
    plt.legend()
    plt.title(f'Testing ACCs for 100 CVs, {str(files[j])}',fontsize =12)
    plt.tight_layout()
    plt.savefig(f'./images/{str(prototype[j])}/ACC_{str(files[j])}.png')
    plt.close()
    print('_____________________________________')
    #____________________________________________________#
     ##export out files to make the next few plots w/o normalization
    pickle.dump(eur_posXtest, open(f'./index/pos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FposXtest, open(f'./index/Fpos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_negXtest, open(f'./index/neg_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FnegXtest, open(f'./index/Fneg_{str(files[j])}.p', 'wb'))
# Out:
# Working on SEUS_ERA5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 62.41%
# Accuracy, Training: 63.25%
# Accuracy, Testing: 61.11%
# ###################################################
# Brier Skill Score (Test): 0.0326
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.6576
# Precision Accuracy Score (Test): 0.6546
# F1 Score (Test): 0.6553
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5509
# Precision Accuracy Score (Train): 0.6237
# F1 Score (Test): 0.5524
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 33.94%
# Average Num. of 10% Confident and Correct Negative Predictions: 36.33%
# Average Num. of 10% Confident and FALSE Postive Predictions: 16.16%
# Average Num. of 10% Confident and FALSE Negative Predictions: 13.57%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 70.26%
# Average Num. of 10% Confident and FALSE Predictions: 29.74%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on SEUS_Prototype5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 62.11%
# Accuracy, Training: 63.22%
# Accuracy, Testing: 58.27%
# ###################################################
# Brier Skill Score (Test): 0.0286
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.6205
# Precision Accuracy Score (Test): 0.5326
# F1 Score (Test): 0.5730
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5515
# Precision Accuracy Score (Train): 0.6233
# F1 Score (Test): 0.5916
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 34.94%
# Average Num. of 10% Confident and Correct Negative Predictions: 35.87%
# Average Num. of 10% Confident and FALSE Postive Predictions: 15.06%
# Average Num. of 10% Confident and FALSE Negative Predictions: 14.13%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 70.82%
# Average Num. of 10% Confident and FALSE Predictions: 29.18%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on SEUS_Prototype6 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 62.30%
# Accuracy, Training: 63.20%
# Accuracy, Testing: 64.07%
# ###################################################
# Brier Skill Score (Test): 0.0724
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.6600
# Precision Accuracy Score (Test): 0.6370
# F1 Score (Test): 0.6481
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.6213
# Precision Accuracy Score (Train): 0.6242
# F1 Score (Test): 0.6328
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 37.56%
# Average Num. of 10% Confident and Correct Negative Predictions: 32.47%
# Average Num. of 10% Confident and FALSE Postive Predictions: 12.47%
# Average Num. of 10% Confident and FALSE Negative Predictions: 17.49%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 70.04%
# Average Num. of 10% Confident and FALSE Predictions: 29.96%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on SEUS_Prototype7 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 62.40%
# Accuracy, Training: 63.17%
# Accuracy, Testing: 61.15%
# ###################################################
# Brier Skill Score (Test): 0.0453
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.6000
# Precision Accuracy Score (Test): 0.5736
# F1 Score (Test): 0.5858
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.6213
# Precision Accuracy Score (Train): 0.6242
# F1 Score (Test): 0.6335
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 35.14%
# Average Num. of 10% Confident and Correct Negative Predictions: 31.56%
# Average Num. of 10% Confident and FALSE Postive Predictions: 14.86%
# Average Num. of 10% Confident and FALSE Negative Predictions: 18.43%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 66.71%
# Average Num. of 10% Confident and FALSE Predictions: 33.29%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on SEUS_Prototype8 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 62.05%
# Accuracy, Training: 63.37%
# Accuracy, Testing: 55.26%
# ###################################################
# Brier Skill Score (Test): -0.0160
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5395
# Precision Accuracy Score (Test): 0.5355
# F1 Score (Test): 0.5368
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5648
# Precision Accuracy Score (Train): 0.6258
# F1 Score (Test): 0.5664
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 29.57%
# Average Num. of 10% Confident and Correct Negative Predictions: 23.76%
# Average Num. of 10% Confident and FALSE Postive Predictions: 20.45%
# Average Num. of 10% Confident and FALSE Negative Predictions: 26.22%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 53.33%
# Average Num. of 10% Confident and FALSE Predictions: 46.67%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
