# %% [markdown]
# ### Random Forests at 14-days leadtime for all regions.
#
# File generated 9/18/2025 for Chapter 4 of Dissertation.
# Modified 12/8/2025 for use in reduced UFS analysis.
#
# This file utilizes definition statements containing RF architecture to create three separate RF models, each for a designated forecast region.
#
# Forecast leadtime can be changed as needed.

# %%
##just to stop the excess number of warnings 
import warnings
warnings.filterwarnings('ignore')

#relevant import statements
import numpy as np
import math
import pandas as pd
import xarray as xr 
import pickle 
import matplotlib.pyplot as plt

import random
from random import seed
from random import randint
from random import sample

import seaborn as sns # statistical data visualization
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.feature_selection import SelectFromModel

import keras
import shap
# Out:
# 2026-01-07 16:10:42.165303: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-07 16:10:42.211586: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-01-07 16:10:42.211623: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-01-07 16:10:42.213210: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-01-07 16:10:42.221507: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-07 16:10:43.608283: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#import definitions 
from SkillStats_MOD import BSS, RAS, PAS

from RF_archMOD import rf_featselect,rf_90thpercentile

# %% [markdown]
# I am going to do a modified version of the architecture def here because I have to change the dataset structure.
#
# Start with bringing in the old data for training/validation.

# %%
#load OG input data, it is max/min standardized, NaNs removed
#stratospheric polar vortex ellipse diagnostics from Fernandez et al 2025 (in review)
infile = open("../old_data/nolag_extendedanom_SEPARATED.p", 'rb') 
nolag_input = pickle.load(infile)
infile.close()

nolag_input.shape
# Out:
# (62, 149, 8)

# %% [markdown]
# The input data stays the same regardless of forecast region.
#
# The original array starts on October 19th. The shift send this forward to November 2nd.

# %%
idx = 135 #129 for 20, 119 for 30.
inp1 = np.empty((52,idx,7)) #cnew input array, 14 day lag. 
shift = 14

##reshaping to change lag in metrics for input
inp1[:,:,0] = nolag_input[:52,shift:,0] ##wind
inp1[:,:,1] = nolag_input[:52,shift:,1] ##ratio
inp1[:,:,2] = nolag_input[:52,shift:,2] ##latitude
inp1[:,:,3] = nolag_input[:52,shift:,3] ##longitude
inp1[:,:,4] = nolag_input[:52,shift:,4] ##size
inp1[:,:,5] = nolag_input[:52,shift:,5] ##ephi
inp1[:,:,6] = nolag_input[:52,shift:,6] ##gph

inp = inp1.reshape(52*idx,7)

#convert to pandas dataframe
input1 = pd.DataFrame(inp)
#label columns of variables for input data
col_names = ['wind','rat','cenlat','cenlon','size','ephi','gph']
input1.columns = col_names

# %%
def testing_data(p):
    infile = open(f'./new_data/input_{str(p)}.p', 'rb') 
    testing_input = pickle.load(infile)
    infile.close()
    
    inp = testing_input.reshape(56*10,7)
    
    #convert to pandas dataframe
    input2 = pd.DataFrame(inp)
    #label columns of variables for input data
    col_names = ['wind','rat','cenlat','cenlon','size','ephi','gph']
    input2.columns = col_names
    return input2

# %% [markdown]
# ### Begin RF Feature selection test.

# %%
def feat_imp_plot(important,input1,files):
    imp = np.nanmean(important, axis = 0)
    imp.shape
    
    #plot features by relative importance
    indices = np.argsort(imp)[::-1]  #sort by importance
    c = ["navy","royalblue","slateblue","blueviolet","darkviolet","purple","mediumvioletred","magenta"]
    
    plt.figure(figsize=(9, 6))
    plt.title(f'Average Feature Importances Across 100 CVs, {str(files)}',fontsize =18)
    plt.barh(range(input1.shape[1]), imp[indices], align="center", color = c)
    plt.yticks(range(input1.shape[1]), input1.columns[indices],fontsize =14)
    plt.xticks(fontsize =14)
    plt.xlabel("Relative Importance",fontsize =16)
    plt.gca().invert_yaxis()
    plt.savefig(f'./images/FeatureImportance_{str(files)}.png',bbox_inches = 'tight')

# %%
#number of cross validations
n = 100

regions = ['eur','nova','seus']

# %%
##Loop through regions and files to do feature selection.
for i in range(len(regions)):
    ##EUROPE
    if regions[i] == 'eur':
        files = ['Europe_ERA5','Europe_Prototype5','Europe_Prototype6','Europe_Prototype7','Europe_Prototype8']
        prototype = ['ERA5','Prototype5','Prototype6','Prototype7','Prototype8']
        for j in range(len(files)):
            print(f'Working on {str(files[j])} ...')
            input2 = testing_data(prototype[j])
            eur_important = rf_featselect(n,shift,idx,input1,input2,regions[i],files[j])
            feat_imp_plot(eur_important,input1,files[j])
            print('_____________________________________')
    ##CANADA
    if regions[i] == 'nova':
        files = ['Canada_ERA5','Canada_Prototype5','Canada_Prototype6','Canada_Prototype7','Canada_Prototype8']
        prototype = ['ERA5','Prototype5','Prototype6','Prototype7','Prototype8']
        for j in range(len(files)):
            print(f'Working on {str(files[j])} ...')
            input2 = testing_data(prototype[j])
            can_important = rf_featselect(n,shift,idx,input1,input2,regions[i],files[j])
            feat_imp_plot(can_important,input1,files[j])
            print('_____________________________________')
    ##SEUS
    if regions[i] == 'seus':
        files = ['SEUS_ERA5','SEUS_Prototype5','SEUS_Prototype6','SEUS_Prototype7','SEUS_Prototype8']
        prototype = ['ERA5','Prototype5','Prototype6','Prototype7','Prototype8']
        for j in range(len(files)):
            print(f'Working on {str(files[j])} ...')
            input2 = testing_data(prototype[j])
            seus_important = rf_featselect(n,shift,idx,input1,input2,regions[i],files[j])
            feat_imp_plot(seus_important,input1,files[j])
            print('_____________________________________')
# Out:
# Working on Europe_ERA5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 58.35%
# Accuracy, Training: 63.01%
# Accuracy, Testing: 64.13%
# _____________________________________
# Working on Europe_Prototype5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 58.32%
# Accuracy, Training: 63.11%
# Accuracy, Testing: 68.10%
# _____________________________________
# Working on Europe_Prototype6 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 58.62%
# Accuracy, Training: 62.98%
# Accuracy, Testing: 60.74%
# _____________________________________
# Working on Europe_Prototype7 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 58.36%
# Accuracy, Training: 63.09%
# Accuracy, Testing: 57.26%
# _____________________________________
# Working on Europe_Prototype8 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 58.56%
# Accuracy, Training: 63.11%
# Accuracy, Testing: 56.46%
# _____________________________________
# Working on Canada_ERA5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 71.32%
# Accuracy, Training: 72.05%
# Accuracy, Testing: 75.07%
# _____________________________________
# Working on Canada_Prototype5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 70.54%
# Accuracy, Training: 72.26%
# Accuracy, Testing: 66.09%
# _____________________________________
# Working on Canada_Prototype6 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 71.24%
# Accuracy, Training: 72.10%
# Accuracy, Testing: 72.64%
# _____________________________________
# Working on Canada_Prototype7 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 71.24%
# Accuracy, Training: 72.08%
# Accuracy, Testing: 70.79%
# _____________________________________
# Working on Canada_Prototype8 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 71.05%
# Accuracy, Training: 72.13%
# Accuracy, Testing: 67.72%
# _____________________________________
# Working on SEUS_ERA5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 62.09%
# Accuracy, Training: 63.20%
# Accuracy, Testing: 59.37%
# _____________________________________
# Working on SEUS_Prototype5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 62.12%
# Accuracy, Training: 63.19%
# Accuracy, Testing: 57.96%
# _____________________________________
# Working on SEUS_Prototype6 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 62.12%
# Accuracy, Training: 63.22%
# Accuracy, Testing: 61.43%
# _____________________________________
# Working on SEUS_Prototype7 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 62.39%
# Accuracy, Training: 63.17%
# Accuracy, Testing: 60.28%
# _____________________________________
# Working on SEUS_Prototype8 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 62.06%
# Accuracy, Training: 63.21%
# Accuracy, Testing: 55.18%
# _____________________________________

# %% [markdown]
# ## Second RF run post feature selection

# %% [markdown]
# ### Europe

# %%
##Loop through regions and files to do feature selection.
prototype = ['ERA5','Prototype5','Prototype6','Prototype7','Prototype8']
####################
files = ['Europe_ERA5','Europe_Prototype5','Europe_Prototype6','Europe_Prototype7','Europe_Prototype8']

for j in range(len(files)):
    print(f'Working on {str(files[j])} ...')
    ##select prototype testing data ...
    input2 = testing_data(prototype[j])
    
    eur_input1 = input1[["wind","cenlon","cenlat","gph"]]
    eur_input2 = input2[["wind","cenlon","cenlat","gph"]]
  
    ##CONSTANT ERA5 OUTPUT
    infile = open(f'./new_data/2classtemps_Europe_ERA5.p',"rb",)
    ERA5_temp = pickle.load(infile) 
    infile.close()

    eur_test90, eur_fulltest, eur_shap_obj, eur_posXtest, eur_FposXtest, eur_negXtest, eur_FnegXtest, acc_reg2_test, acc_reg3_test, acc_reg4_test = rf_90thpercentile(n,shift, idx, eur_input1, eur_input2, ERA5_temp, 'eur', files[j])
    #____________________________________________________#
    #plot SHAP
    plt.title(f'SHAP Values for Negative Europe Temp Anomalies, {str(files[j])}',fontsize =14, y = 1.05)
    ax = shap.plots.beeswarm(eur_shap_obj[:,:,0], show = False) ##for negative classifications ... this is physically consistent!
    plt.tight_layout()
    plt.savefig(f'./images/SHAP_{str(files[j])}.png')
    plt.close()
    #____________________________________________________#
    #plot ACC
    bins = np.linspace(0.4, 1,13)  # 10 bins from 0.4 to 1
    ##bin the testing 90th percentile accuracy data
    counts90, edges90 = np.histogram(eur_test90, bins=bins)
    countsfull, edgesfull = np.histogram(eur_fulltest, bins=bins)
    counts_era5, edges_era5= np.histogram(acc_reg3_test, bins=bins) ##relative to ERA5 truth
    #plot the full dataset
    #offset = 0.02  # Adjust this value if needed for better visibility
    plt.bar(edgesfull[:-1], countsfull, width=np.diff(edgesfull), 
            edgecolor='black', alpha=0.5, label='All Predictions', align='edge', color='blue')
    
    #plot the 90th percentile
    plt.bar(edges90[:-1], counts90, width=np.diff(edges90), 
            edgecolor='black', alpha=0.5, label='>90th Percentile Predictions', align='edge', color = 'lightblue')
    
    #plot the ERA-5 comparison
    plt.bar(edges_era5[:-1], counts_era5, width=np.diff(edges_era5), 
            edgecolor='black', alpha=0.5, label='Predictions vs. ERA-5 Truth', align='edge', color = 'indigo')
    
    plt.xlabel('Accuracy',fontsize =14)
    plt.ylabel('Number of Models',fontsize =14)
    plt.legend()
    plt.title(f'Testing ACCs for 100 CVs, {str(files[j])}',fontsize =12)
    plt.tight_layout()
    plt.savefig(f'./images/ACC_{str(files[j])}.png')
    plt.close()
    print('_____________________________________')
    #____________________________________________________#
    ##export out files to make the next few plots w/o normalization
    pickle.dump(eur_posXtest, open(f'./index/pos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FposXtest, open(f'./index/Fpos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_negXtest, open(f'./index/neg_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FnegXtest, open(f'./index/Fneg_{str(files[j])}.p', 'wb'))
# Out:
# Working on Europe_ERA5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 57.60%
# Accuracy, Training: 62.28%
# Accuracy, Testing: 61.60%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0725
# Brier Skill Score (Test): 0.0567
# Brier Skill Score (Validation): 0.0224
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7341
# Recall Accuracy Score (Test): 0.6709
# Recall AccuracyScore (Validation): 0.6899
# Precision Accuracy Score (Train): 0.6158
# Precision Accuracy Score (Test): 0.5983
# Precision AccuracyScore (Validation): 0.5763
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5014
# Recall Accuracy Score (Test): 0.5629
# Recall AccuracyScore (Validation): 0.4566
# Precision Accuracy Score (Train): 0.6354
# Precision Accuracy Score (Test): 0.6416
# Precision AccuracyScore (Validation): 0.5800
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 41.10%
# Average Num. of 10% Confident and Correct Negative Predictions: 29.88%
# Average Num. of 10% Confident and FALSE Postive Predictions: 8.89%
# Average Num. of 10% Confident and FALSE Negative Predictions: 20.13%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 70.98%
# Average Num. of 10% Confident and FALSE Predictions: 29.02%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Europe_Prototype5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 58.34%
# Accuracy, Training: 62.05%
# Accuracy, Testing: 65.91%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0707
# Brier Skill Score (Test): 0.0816
# Brier Skill Score (Validation): 0.0286
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7275
# Recall Accuracy Score (Test): 0.7922
# Recall AccuracyScore (Validation): 0.6940
# Precision Accuracy Score (Train): 0.6141
# Precision Accuracy Score (Test): 0.5970
# Precision AccuracyScore (Validation): 0.5863
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5040
# Recall Accuracy Score (Test): 0.5462
# Recall AccuracyScore (Validation): 0.4662
# Precision Accuracy Score (Train): 0.6319
# Precision Accuracy Score (Test): 0.7634
# Precision AccuracyScore (Validation): 0.5838
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 46.89%
# Average Num. of 10% Confident and Correct Negative Predictions: 38.72%
# Average Num. of 10% Confident and FALSE Postive Predictions: 3.12%
# Average Num. of 10% Confident and FALSE Negative Predictions: 11.27%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 85.61%
# Average Num. of 10% Confident and FALSE Predictions: 14.39%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Europe_Prototype6 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 57.50%
# Accuracy, Training: 62.27%
# Accuracy, Testing: 58.72%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0727
# Brier Skill Score (Test): 0.0485
# Brier Skill Score (Validation): 0.0213
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7351
# Recall Accuracy Score (Test): 0.7097
# Recall AccuracyScore (Validation): 0.6858
# Precision Accuracy Score (Train): 0.6151
# Precision Accuracy Score (Test): 0.5539
# Precision AccuracyScore (Validation): 0.5778
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5004
# Recall Accuracy Score (Test): 0.4756
# Recall AccuracyScore (Validation): 0.4578
# Precision Accuracy Score (Train): 0.6363
# Precision Accuracy Score (Test): 0.6435
# Precision AccuracyScore (Validation): 0.5747
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 41.92%
# Average Num. of 10% Confident and Correct Negative Predictions: 38.68%
# Average Num. of 10% Confident and FALSE Postive Predictions: 8.06%
# Average Num. of 10% Confident and FALSE Negative Predictions: 11.34%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 80.60%
# Average Num. of 10% Confident and FALSE Predictions: 19.40%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Europe_Prototype7 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 57.95%
# Accuracy, Training: 62.23%
# Accuracy, Testing: 57.59%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0715
# Brier Skill Score (Test): 0.0206
# Brier Skill Score (Validation): 0.0247
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7336
# Recall Accuracy Score (Test): 0.6725
# Recall AccuracyScore (Validation): 0.6902
# Precision Accuracy Score (Train): 0.6152
# Precision Accuracy Score (Test): 0.5528
# Precision AccuracyScore (Validation): 0.5813
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5011
# Recall Accuracy Score (Test): 0.4847
# Recall AccuracyScore (Validation): 0.4635
# Precision Accuracy Score (Train): 0.6351
# Precision Accuracy Score (Test): 0.6122
# Precision AccuracyScore (Validation): 0.5822
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 32.73%
# Average Num. of 10% Confident and Correct Negative Predictions: 29.21%
# Average Num. of 10% Confident and FALSE Postive Predictions: 17.27%
# Average Num. of 10% Confident and FALSE Negative Predictions: 20.79%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 61.93%
# Average Num. of 10% Confident and FALSE Predictions: 38.07%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Europe_Prototype8 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 57.94%
# Accuracy, Training: 62.27%
# Accuracy, Testing: 56.88%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0716
# Brier Skill Score (Test): 0.0280
# Brier Skill Score (Validation): 0.0262
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7324
# Recall Accuracy Score (Test): 0.6677
# Recall AccuracyScore (Validation): 0.6880
# Precision Accuracy Score (Train): 0.6159
# Precision Accuracy Score (Test): 0.5662
# Precision AccuracyScore (Validation): 0.5804
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5031
# Recall Accuracy Score (Test): 0.4656
# Recall AccuracyScore (Validation): 0.4655
# Precision Accuracy Score (Train): 0.6346
# Precision Accuracy Score (Test): 0.5746
# Precision AccuracyScore (Validation): 0.5827
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 36.76%
# Average Num. of 10% Confident and Correct Negative Predictions: 36.89%
# Average Num. of 10% Confident and FALSE Postive Predictions: 13.18%
# Average Num. of 10% Confident and FALSE Negative Predictions: 13.17%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 73.65%
# Average Num. of 10% Confident and FALSE Predictions: 26.35%
#
#
# Trying SHAP ...
# Done.
# _____________________________________

# %% [markdown]
# ### Canada

# %%
##Loop through regions and files to do feature selection.
files = ['Canada_ERA5','Canada_Prototype5','Canada_Prototype6','Canada_Prototype7','Canada_Prototype8']

for j in range(len(files)):
    print(f'Working on {str(files[j])} ...')

    input2 = testing_data(prototype[j])
    eur_input1 = input1[["wind","cenlon","cenlat","gph"]]
    eur_input2 = input2[["wind","cenlon","cenlat","gph"]]

    ##CONSTANT ERA5 OUTPUT
    infile = open(f'./new_data/2classtemps_Canada_ERA5.p',"rb",)
    ERA5_temp = pickle.load(infile) 
    infile.close()
    
    eur_test90, eur_fulltest, eur_shap_obj, eur_posXtest, eur_FposXtest, eur_negXtest, eur_FnegXtest, acc_reg2_test, acc_reg3_test, acc_reg4_test = rf_90thpercentile(n,shift, idx, eur_input1, eur_input2, ERA5_temp, 'nova',files[j])
    #____________________________________________________#
    #plot SHAP
    plt.title(f'SHAP Values for Negative Canadian Temp Anomalies, {str(files[j])}',fontsize =14, y = 1.05)
    ax = shap.plots.beeswarm(eur_shap_obj[:,:,0], show = False) ##for negative classifications ... this is physically consistent!
    plt.tight_layout()
    plt.savefig(f'./images/SHAP_{str(files[j])}.png')
    plt.close()
    #____________________________________________________#
    #plot ACC
    bins = np.linspace(0.4, 1,13)  # 10 bins from 0.4 to 1
    ##bin the testing 90th percentile accuracy data
    counts90, edges90 = np.histogram(eur_test90, bins=bins)
    countsfull, edgesfull = np.histogram(eur_fulltest, bins=bins)
    counts_era5, edges_era5= np.histogram(acc_reg3_test, bins=bins) ##relative to ERA5 truth
    #plot the full dataset
    #offset = 0.02  # Adjust this value if needed for better visibility
    plt.bar(edgesfull[:-1], countsfull, width=np.diff(edgesfull), 
            edgecolor='black', alpha=0.5, label='All Predictions', align='edge', color='blue')
    
    #plot the 90th percentile
    plt.bar(edges90[:-1], counts90, width=np.diff(edges90), 
            edgecolor='black', alpha=0.5, label='>90th Percentile Predictions', align='edge', color = 'lightblue')
    
    #plot the ERA-5 comparison
    plt.bar(edges_era5[:-1], counts_era5, width=np.diff(edges_era5), 
            edgecolor='black', alpha=0.5, label='Predictions vs. ERA-5 Truth', align='edge', color = 'indigo')
    
    plt.xlabel('Accuracy',fontsize =14)
    plt.ylabel('Number of Models',fontsize =14)
    plt.legend()
    plt.title(f'Testing ACCs for 100 CVs, {str(files[j])}',fontsize =12)
    plt.tight_layout()
    plt.savefig(f'./images/ACC_{str(files[j])}.png')
    plt.close()
    print('_____________________________________')
    #____________________________________________________#
    ##export out files to make the next few plots w/o normalization
    pickle.dump(eur_posXtest, open(f'./index/pos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FposXtest, open(f'./index/Fpos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_negXtest, open(f'./index/neg_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FnegXtest, open(f'./index/Fneg_{str(files[j])}.p', 'wb'))
# Out:
# Working on Canada_ERA5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 71.17%
# Accuracy, Training: 72.06%
# Accuracy, Testing: 76.24%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.2272
# Brier Skill Score (Test): 0.2074
# Brier Skill Score (Validation): 0.1944
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.8860
# Recall Accuracy Score (Test): 0.8871
# Recall AccuracyScore (Validation): 0.8794
# Precision Accuracy Score (Train): 0.7023
# Precision Accuracy Score (Test): 0.7590
# Precision AccuracyScore (Validation): 0.6983
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5006
# Recall Accuracy Score (Test): 0.5739
# Recall AccuracyScore (Validation): 0.4858
# Precision Accuracy Score (Train): 0.7677
# Precision Accuracy Score (Test): 0.7773
# Precision AccuracyScore (Validation): 0.7497
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 42.97%
# Average Num. of 10% Confident and Correct Negative Predictions: 31.10%
# Average Num. of 10% Confident and FALSE Postive Predictions: 7.02%
# Average Num. of 10% Confident and FALSE Negative Predictions: 18.91%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 74.08%
# Average Num. of 10% Confident and FALSE Predictions: 25.92%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Canada_Prototype5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 71.04%
# Accuracy, Training: 72.08%
# Accuracy, Testing: 67.39%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.2279
# Brier Skill Score (Test): 0.1184
# Brier Skill Score (Validation): 0.1918
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.8853
# Recall Accuracy Score (Test): 0.8942
# Recall AccuracyScore (Validation): 0.8806
# Precision Accuracy Score (Train): 0.7029
# Precision Accuracy Score (Test): 0.6185
# Precision AccuracyScore (Validation): 0.6960
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5020
# Recall Accuracy Score (Test): 0.4568
# Recall AccuracyScore (Validation): 0.4821
# Precision Accuracy Score (Train): 0.7669
# Precision Accuracy Score (Test): 0.8223
# Precision AccuracyScore (Validation): 0.7512
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 46.80%
# Average Num. of 10% Confident and Correct Negative Predictions: 33.12%
# Average Num. of 10% Confident and FALSE Postive Predictions: 3.18%
# Average Num. of 10% Confident and FALSE Negative Predictions: 16.90%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 79.92%
# Average Num. of 10% Confident and FALSE Predictions: 20.08%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Canada_Prototype6 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 70.78%
# Accuracy, Training: 72.17%
# Accuracy, Testing: 73.81%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.2299
# Brier Skill Score (Test): 0.2101
# Brier Skill Score (Validation): 0.1843
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.8865
# Recall Accuracy Score (Test): 0.9154
# Recall AccuracyScore (Validation): 0.8758
# Precision Accuracy Score (Train): 0.7031
# Precision Accuracy Score (Test): 0.7038
# Precision AccuracyScore (Validation): 0.6963
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5030
# Recall Accuracy Score (Test): 0.5150
# Recall AccuracyScore (Validation): 0.4801
# Precision Accuracy Score (Train): 0.7695
# Precision Accuracy Score (Test): 0.8364
# Precision AccuracyScore (Validation): 0.7398
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 47.94%
# Average Num. of 10% Confident and Correct Negative Predictions: 40.19%
# Average Num. of 10% Confident and FALSE Postive Predictions: 1.97%
# Average Num. of 10% Confident and FALSE Negative Predictions: 9.91%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 88.13%
# Average Num. of 10% Confident and FALSE Predictions: 11.87%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Canada_Prototype7 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 71.19%
# Accuracy, Training: 72.06%
# Accuracy, Testing: 71.54%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.2282
# Brier Skill Score (Test): 0.1677
# Brier Skill Score (Validation): 0.1910
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.8859
# Recall Accuracy Score (Test): 0.9153
# Recall AccuracyScore (Validation): 0.8847
# Precision Accuracy Score (Train): 0.7024
# Precision Accuracy Score (Test): 0.6548
# Precision AccuracyScore (Validation): 0.6969
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5008
# Recall Accuracy Score (Test): 0.5141
# Recall AccuracyScore (Validation): 0.4795
# Precision Accuracy Score (Train): 0.7676
# Precision Accuracy Score (Test): 0.8643
# Precision AccuracyScore (Validation): 0.7552
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 48.21%
# Average Num. of 10% Confident and Correct Negative Predictions: 41.45%
# Average Num. of 10% Confident and FALSE Postive Predictions: 1.73%
# Average Num. of 10% Confident and FALSE Negative Predictions: 8.61%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 89.67%
# Average Num. of 10% Confident and FALSE Predictions: 10.33%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Canada_Prototype8 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 71.62%
# Accuracy, Training: 71.93%
# Accuracy, Testing: 67.61%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.2246
# Brier Skill Score (Test): 0.1661
# Brier Skill Score (Validation): 0.2043
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.8849
# Recall Accuracy Score (Test): 0.8589
# Recall AccuracyScore (Validation): 0.8811
# Precision Accuracy Score (Train): 0.7014
# Precision Accuracy Score (Test): 0.6448
# Precision AccuracyScore (Validation): 0.7024
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.4993
# Recall Accuracy Score (Test): 0.4726
# Recall AccuracyScore (Validation): 0.4940
# Precision Accuracy Score (Train): 0.7656
# Precision Accuracy Score (Test): 0.7547
# Precision AccuracyScore (Validation): 0.7555
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 44.54%
# Average Num. of 10% Confident and Correct Negative Predictions: 45.82%
# Average Num. of 10% Confident and FALSE Postive Predictions: 5.42%
# Average Num. of 10% Confident and FALSE Negative Predictions: 4.22%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 90.36%
# Average Num. of 10% Confident and FALSE Predictions: 9.64%
#
#
# Trying SHAP ...
# Done.
# _____________________________________

# %% [markdown]
# ### SEUS

# %%
##Loop through regions and files to do feature selection.
files = ['SEUS_ERA5','SEUS_Prototype5','SEUS_Prototype6','SEUS_Prototype7','SEUS_Prototype8']

for j in range(len(files)):
    print(f'Working on {str(files[j])} ...')
    
    input2 = testing_data(prototype[j])
    eur_input1 = input1[["wind","size","cenlat","gph"]]
    eur_input2 = input2[["wind","size","cenlat","gph"]]

    ##CONSTANT ERA5 OUTPUT
    infile = open(f'./new_data/2classtemps_SEUS_ERA5.p',"rb",)
    ERA5_temp = pickle.load(infile) 
    infile.close()
    
    eur_test90, eur_fulltest, eur_shap_obj, eur_posXtest, eur_FposXtest, eur_negXtest, eur_FnegXtest, acc_reg2_test, acc_reg3_test, acc_reg4_test = rf_90thpercentile(n,shift, idx, eur_input1, eur_input2, ERA5_temp, 'seus', files[j])
    #____________________________________________________#
    #plot SHAP
    plt.title(f'SHAP Values for SEUS Temp Anomalies, {str(files[j])}',fontsize =14, y = 1.05)
    ax = shap.plots.beeswarm(eur_shap_obj[:,:,0], show = False) ##for negative classifications ... this is physically consistent!
    plt.tight_layout()
    plt.savefig(f'./images/SHAP_{str(files[j])}.png')
    plt.close()
    #____________________________________________________#
    #plot ACC
    bins = np.linspace(0.4, 1,13)  # 10 bins from 0.4 to 1
    ##bin the testing 90th percentile accuracy data
    counts90, edges90 = np.histogram(eur_test90, bins=bins)
    countsfull, edgesfull = np.histogram(eur_fulltest, bins=bins)
    counts_era5, edges_era5= np.histogram(acc_reg3_test, bins=bins) ##relative to ERA5 truth
    #plot the full dataset
    #offset = 0.02  # Adjust this value if needed for better visibility
    plt.bar(edgesfull[:-1], countsfull, width=np.diff(edgesfull), 
            edgecolor='black', alpha=0.5, label='All Predictions', align='edge', color='blue')
    
    #plot the 90th percentile
    plt.bar(edges90[:-1], counts90, width=np.diff(edges90), 
            edgecolor='black', alpha=0.5, label='>90th Percentile Predictions', align='edge', color = 'lightblue')
    
    #plot the ERA-5 comparison
    plt.bar(edges_era5[:-1], counts_era5, width=np.diff(edges_era5), 
            edgecolor='black', alpha=0.5, label='Predictions vs. ERA-5 Truth', align='edge', color = 'indigo')
    
    plt.xlabel('Accuracy',fontsize =14)
    plt.ylabel('Number of Models',fontsize =14)
    plt.legend()
    plt.title(f'Testing ACCs for 100 CVs, {str(files[j])}',fontsize =12)
    plt.tight_layout()
    plt.savefig(f'./images/ACC_{str(files[j])}.png')
    plt.close()
    print('_____________________________________')
    #____________________________________________________#
     ##export out files to make the next few plots w/o normalization
    pickle.dump(eur_posXtest, open(f'./index/pos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FposXtest, open(f'./index/Fpos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_negXtest, open(f'./index/neg_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FnegXtest, open(f'./index/Fneg_{str(files[j])}.p', 'wb'))
# Out:
# Working on SEUS_ERA5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
