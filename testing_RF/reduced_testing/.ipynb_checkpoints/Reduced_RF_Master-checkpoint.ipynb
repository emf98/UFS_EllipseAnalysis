# %% [markdown]
# ### Random Forests at 14-days leadtime for all regions.
#
# File generated 9/18/2025 for Chapter 4 of Dissertation.
# Modified 12/8/2025 for use in reduced UFS analysis.
#
# This file utilizes definition statements containing RF architecture to create three separate RF models, each for a designated forecast region.
#
# Forecast leadtime can be changed as needed.

# %%
##just to stop the excess number of warnings 
import warnings
warnings.filterwarnings('ignore')

#relevant import statements
import numpy as np
import math
import pandas as pd
import xarray as xr 
import pickle 
import matplotlib.pyplot as plt

import random
from random import seed
from random import randint
from random import sample

import seaborn as sns # statistical data visualization
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.feature_selection import SelectFromModel

import keras
import shap
# Out:
# 2026-02-05 20:10:47.747870: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 20:10:47.924767: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-02-05 20:10:47.924796: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-02-05 20:10:47.926066: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-02-05 20:10:48.006770: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-05 20:11:00.913219: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#import definitions 
from SkillStats_MOD import BSS, RAS, PAS

from RF_archMOD import rf_featselect,rf_90thpercentile

# %% [markdown]
# I am going to do a modified version of the architecture def here because I have to change the dataset structure.
#
# Start with bringing in the old data for training/validation.

# %%
#load OG input data, it is max/min standardized, NaNs removed
#stratospheric polar vortex ellipse diagnostics from Fernandez et al 2025 (in review)
infile = open("../old_data/nolag_extendedanom_SEPARATED.p", 'rb') 
nolag_input = pickle.load(infile)
infile.close()

nolag_input.shape
# Out:
# (62, 149, 8)

# %% [markdown]
# The input data stays the same regardless of forecast region.
#
# The original array starts on October 19th. The shift send this forward to November 2nd.

# %%
idx = 135 #129 for 20, 119 for 30.
inp1 = np.empty((52,idx,7)) #cnew input array, 14 day lag. 
shift = 14

##reshaping to change lag in metrics for input
inp1[:,:,0] = nolag_input[:52,shift:,0] ##wind
inp1[:,:,1] = nolag_input[:52,shift:,1] ##ratio
inp1[:,:,2] = nolag_input[:52,shift:,2] ##latitude
inp1[:,:,3] = nolag_input[:52,shift:,3] ##longitude
inp1[:,:,4] = nolag_input[:52,shift:,4] ##size
inp1[:,:,5] = nolag_input[:52,shift:,5] ##ephi
inp1[:,:,6] = nolag_input[:52,shift:,6] ##gph

inp = inp1.reshape(52*idx,7)

#convert to pandas dataframe
input1 = pd.DataFrame(inp)
#label columns of variables for input data
col_names = ['wind','rat','cenlat','cenlon','size','ephi','gph']
input1.columns = col_names

# %%
def testing_data(p):
    infile = open(f'./new_data/input_{str(p)}.p', 'rb') 
    testing_input = pickle.load(infile)
    infile.close()
    
    inp = testing_input.reshape(56*10,7)
    
    #convert to pandas dataframe
    input2 = pd.DataFrame(inp)
    #label columns of variables for input data
    col_names = ['wind','rat','cenlat','cenlon','size','ephi','gph']
    input2.columns = col_names
    return input2

# %% [markdown]
# ### Begin RF Feature selection test.

# %%
def feat_imp_plot(important,input1,files,prototype):
    imp = np.nanmean(important, axis = 0)
    imp.shape
    
    #plot features by relative importance
    indices = np.argsort(imp)[::-1]  #sort by importance
    c = ["navy","royalblue","slateblue","blueviolet","darkviolet","purple","mediumvioletred","magenta"]
    
    plt.figure(figsize=(9, 6))
    plt.title(f'Average Feature Importances Across 100 CVs, {str(files)}',fontsize =18)
    plt.barh(range(input1.shape[1]), imp[indices], align="center", color = c)
    plt.yticks(range(input1.shape[1]), input1.columns[indices],fontsize =14)
    plt.xticks(fontsize =14)
    plt.xlabel("Relative Importance",fontsize =16)
    plt.gca().invert_yaxis()
    plt.savefig(f'./images/{str(prototype)}/FeatureImportance_{str(files)}.png',bbox_inches = 'tight')
    plt.close()

# %%
def SHAP_imp_plot(shap_obj, files, prototype):
    plt.title("SHAP Values for Negative Temp Anomalies",fontsize =14, y = 1.05)
    ax = shap.plots.beeswarm(shap_obj[:,:,0], show = False) ##for negative classifications ... this is physically consistent!
    #ax.set_xlim(-0.3,0.3)  
    plt.savefig(f'./images/{str(prototype)}/SHAP_FeatureImportance_{str(files)}.png',bbox_inches = 'tight')
    plt.close()

# %%
#number of cross validations
n = 100

regions = ['eur','nova','seus']

#list for top 90%?
eur_feats = []
nova_feats = []
seus_feats = []

# %%
##Loop through regions and files to do feature selection.
for i in range(len(regions)):
    ##EUROPE
    if regions[i] == 'eur':
        files = ['Europe_ERA5','Europe_Prototype5','Europe_Prototype6','Europe_Prototype7','Europe_Prototype8']
        prototype = ['ERA5','Prototype5','Prototype6','Prototype7','Prototype8']
        for j in range(len(files)):
            print(f'Working on {str(files[j])} ...')
            input2 = testing_data(prototype[j])
            eur_important, eur_top90_idx, eur_shap_obj = rf_featselect(n,shift,idx,input1,input2,regions[i],files[j])
            ##OG Feature Importance
            feat_imp_plot(eur_important,input1,files[j], prototype[j])
            ##SHAP Feature Importance
            SHAP_imp_plot(eur_shap_obj,files[j], prototype[j])
            #Save top 90% to list
            eur_feats.append(eur_top90_idx)
            print('_____________________________________')
            
    ##CANADA
    if regions[i] == 'nova':
        files = ['Canada_ERA5','Canada_Prototype5','Canada_Prototype6','Canada_Prototype7','Canada_Prototype8']
        prototype = ['ERA5','Prototype5','Prototype6','Prototype7','Prototype8']
        for j in range(len(files)):
            print(f'Working on {str(files[j])} ...')
            input2 = testing_data(prototype[j])
            can_important, can_top90_idx, can_shap_obj  = rf_featselect(n,shift,idx,input1,input2,regions[i],files[j])
            ##OG Feature Importance
            feat_imp_plot(can_important,input1, files[j], prototype[j])
            ##SHAP Feature Importance
            SHAP_imp_plot(can_shap_obj, files[j], prototype[j])
            #Save top 90% to list
            nova_feats.append(can_top90_idx)
            print('_____________________________________')
            
    ##SEUS
    if regions[i] == 'seus':
        files = ['SEUS_ERA5','SEUS_Prototype5','SEUS_Prototype6','SEUS_Prototype7','SEUS_Prototype8']
        prototype = ['ERA5','Prototype5','Prototype6','Prototype7','Prototype8']
        for j in range(len(files)):
            print(f'Working on {str(files[j])} ...')
            input2 = testing_data(prototype[j])
            seus_important, seus_top90_idx, seus_shap_obj = rf_featselect(n,shift,idx,input1,input2,regions[i],files[j])
            ##OG Feature Importance
            feat_imp_plot(seus_important,input1, files[j], prototype[j])
            ##SHAP Feature Importance
            SHAP_imp_plot(seus_shap_obj, files[j], prototype[j])
            #Save top 90% to list
            seus_feats.append(seus_top90_idx)
            print('_____________________________________')
# Out:
# Working on Europe_ERA5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 58.24%
# Accuracy, Training: 63.11%
# Accuracy, Testing: 64.35%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 6 features explain 90% of total SHAP importance
# _____________________________________
# Working on Europe_Prototype5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 58.27%
# Accuracy, Training: 63.15%
# Accuracy, Testing: 68.10%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 6 features explain 90% of total SHAP importance
# _____________________________________
# Working on Europe_Prototype6 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 58.00%
# Accuracy, Training: 63.17%
# Accuracy, Testing: 60.91%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 6 features explain 90% of total SHAP importance
# _____________________________________
# Working on Europe_Prototype7 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 57.89%
# Accuracy, Training: 63.17%
# Accuracy, Testing: 57.19%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 6 features explain 90% of total SHAP importance
# _____________________________________
# Working on Europe_Prototype8 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 58.38%
# Accuracy, Training: 63.12%
# Accuracy, Testing: 55.97%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 6 features explain 90% of total SHAP importance
# _____________________________________
# Working on Canada_ERA5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 71.28%
# Accuracy, Training: 72.06%
# Accuracy, Testing: 75.13%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 4 features explain 90% of total SHAP importance
# _____________________________________
# Working on Canada_Prototype5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 71.39%
# Accuracy, Training: 72.03%
# Accuracy, Testing: 66.33%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 4 features explain 90% of total SHAP importance
# _____________________________________
# Working on Canada_Prototype6 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 70.59%
# Accuracy, Training: 72.27%
# Accuracy, Testing: 72.61%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 4 features explain 90% of total SHAP importance
# _____________________________________
# Working on Canada_Prototype7 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 71.53%
# Accuracy, Training: 72.02%
# Accuracy, Testing: 70.92%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 4 features explain 90% of total SHAP importance
# _____________________________________
# Working on Canada_Prototype8 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 71.12%
# Accuracy, Training: 72.10%
# Accuracy, Testing: 67.69%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 4 features explain 90% of total SHAP importance
# _____________________________________
# Working on SEUS_ERA5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 62.19%
# Accuracy, Training: 63.22%
# Accuracy, Testing: 58.96%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 5 features explain 90% of total SHAP importance
# _____________________________________
# Working on SEUS_Prototype5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 62.31%
# Accuracy, Training: 63.14%
# Accuracy, Testing: 58.26%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 5 features explain 90% of total SHAP importance
# _____________________________________
# Working on SEUS_Prototype6 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 62.33%
# Accuracy, Training: 63.16%
# Accuracy, Testing: 61.79%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 5 features explain 90% of total SHAP importance
# _____________________________________
# Working on SEUS_Prototype7 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 62.28%
# Accuracy, Training: 63.15%
# Accuracy, Testing: 60.20%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 5 features explain 90% of total SHAP importance
# _____________________________________
# Working on SEUS_Prototype8 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 62.13%
# Accuracy, Training: 63.19%
# Accuracy, Testing: 55.09%
# ###################################################
# SHAP feature selection ...
# (560, 7, 2)
# 5 features explain 90% of total SHAP importance
# _____________________________________

# %% [markdown]
# ## Second RF run post feature selection

# %% [markdown]
# ### Europe

# %%
##Loop through regions and files to do feature selection.
prototype = ['ERA5','Prototype5','Prototype6','Prototype7','Prototype8']
####################
files = ['Europe_ERA5','Europe_Prototype5','Europe_Prototype6','Europe_Prototype7','Europe_Prototype8']

for j in range(len(files)):
    print(f'Working on {str(files[j])} ...')
    ##select prototype testing data ...
    input2 = testing_data(prototype[j])
    
    #eur_input1 = input1[input1.columns[eur_feats[j]]]
    #eur_input2 = input2[input2.columns[eur_feats[j]]]
    ##commenting out feature selection just to test how that affects the model ...
    eur_input1 = input1
    eur_input2 = input2
  
    ##CONSTANT ERA5 OUTPUT
    infile = open(f'./new_data/2classtemps_Europe_ERA5.p',"rb",)
    ERA5_temp = pickle.load(infile) 
    infile.close()

    eur_test90, eur_fulltest, eur_shap_obj, eur_posXtest, eur_FposXtest, eur_negXtest, eur_FnegXtest, acc_reg2_test, acc_reg3_test, acc_reg4_test = rf_90thpercentile(n,shift, idx, eur_input1, eur_input2, ERA5_temp, 'eur', files[j])
    #____________________________________________________#
    #plot SHAP
    plt.title(f'SHAP Values for Negative Europe Temp Anomalies, {str(files[j])}',fontsize =14, y = 1.05)
    ax = shap.plots.beeswarm(eur_shap_obj[:,:,0], show = False) ##for negative classifications ... this is physically consistent!
    plt.tight_layout()
    plt.savefig(f'./images/{str(prototype[j])}/All_SHAP_{str(files[j])}.png')
    plt.close()
    #____________________________________________________#
    #plot ACC
    bins = np.linspace(0.4, 1,13)  # 10 bins from 0.4 to 1
    ##bin the testing 90th percentile accuracy data
    counts90, edges90 = np.histogram(eur_test90, bins=bins)
    countsfull, edgesfull = np.histogram(eur_fulltest, bins=bins)
    counts_era5, edges_era5= np.histogram(acc_reg3_test, bins=bins) ##relative to ERA5 truth
    #plot the full dataset
    #offset = 0.02  # Adjust this value if needed for better visibility
    plt.bar(edgesfull[:-1], countsfull, width=np.diff(edgesfull), 
            edgecolor='black', alpha=0.5, label='All Predictions', align='edge', color='blue')
    
    #plot the 90th percentile
    plt.bar(edges90[:-1], counts90, width=np.diff(edges90), 
            edgecolor='black', alpha=0.5, label='>90th Percentile Predictions', align='edge', color = 'lightblue')
    
    #plot the ERA-5 comparison
    plt.bar(edges_era5[:-1], counts_era5, width=np.diff(edges_era5), 
            edgecolor='black', alpha=0.5, label='Predictions vs. ERA-5 Truth', align='edge', color = 'indigo')
    
    plt.xlabel('Accuracy',fontsize =14)
    plt.ylabel('Number of Models',fontsize =14)
    plt.ylim(0,105)
    plt.legend()
    plt.title(f'Testing ACCs for 100 CVs, {str(files[j])}',fontsize =12)
    plt.tight_layout()
    plt.savefig(f'./images/{str(prototype[j])}/All_ACC_{str(files[j])}.png')
    plt.close()
    print('_____________________________________')
    #____________________________________________________#
    ##export out files to make the next few plots w/o normalization
    pickle.dump(eur_posXtest, open(f'./index/All_pos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FposXtest, open(f'./index/All_Fpos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_negXtest, open(f'./index/All_neg_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FnegXtest, open(f'./index/All_Fneg_{str(files[j])}.p', 'wb'))
# Out:
# Working on Europe_ERA5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 58.51%
# Accuracy, Training: 63.01%
# Accuracy, Testing: 64.38%
# ###################################################
# Brier Skill Score (Test): 0.0672
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.6967
# Precision Accuracy Score (Test): 0.6235
# F1 Score (Test): 0.6566
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5928
# Precision Accuracy Score (Train): 0.6509
# F1 Score (Test): 0.6278
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 40.10%
# Average Num. of 10% Confident and Correct Negative Predictions: 37.26%
# Average Num. of 10% Confident and FALSE Postive Predictions: 9.89%
# Average Num. of 10% Confident and FALSE Negative Predictions: 12.75%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 77.36%
# Average Num. of 10% Confident and FALSE Predictions: 22.64%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Europe_Prototype5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 58.13%
# Accuracy, Training: 63.05%
# Accuracy, Testing: 68.33%
# ###################################################
# Brier Skill Score (Test): 0.0945
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.7684
# Precision Accuracy Score (Test): 0.6272
# F1 Score (Test): 0.6894
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.6112
# Precision Accuracy Score (Train): 0.6520
# F1 Score (Test): 0.6755
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 48.06%
# Average Num. of 10% Confident and Correct Negative Predictions: 38.15%
# Average Num. of 10% Confident and FALSE Postive Predictions: 1.94%
# Average Num. of 10% Confident and FALSE Negative Predictions: 11.85%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 86.21%
# Average Num. of 10% Confident and FALSE Predictions: 13.79%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Europe_Prototype6 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 57.91%
# Accuracy, Training: 63.13%
# Accuracy, Testing: 60.53%
# ###################################################
# Brier Skill Score (Test): 0.0599
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.6875
# Precision Accuracy Score (Test): 0.5724
# F1 Score (Test): 0.6234
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5303
# Precision Accuracy Score (Train): 0.6531
# F1 Score (Test): 0.5830
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 44.25%
# Average Num. of 10% Confident and Correct Negative Predictions: 35.31%
# Average Num. of 10% Confident and FALSE Postive Predictions: 5.72%
# Average Num. of 10% Confident and FALSE Negative Predictions: 14.71%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 79.56%
# Average Num. of 10% Confident and FALSE Predictions: 20.44%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Europe_Prototype7 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 57.87%
# Accuracy, Training: 63.12%
# Accuracy, Testing: 57.13%
# ###################################################
# Brier Skill Score (Test): 0.0163
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.6023
# Precision Accuracy Score (Test): 0.5543
# F1 Score (Test): 0.5756
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5419
# Precision Accuracy Score (Train): 0.6518
# F1 Score (Test): 0.5640
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 33.40%
# Average Num. of 10% Confident and Correct Negative Predictions: 22.86%
# Average Num. of 10% Confident and FALSE Postive Predictions: 16.60%
# Average Num. of 10% Confident and FALSE Negative Predictions: 27.14%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 56.27%
# Average Num. of 10% Confident and FALSE Predictions: 43.73%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Europe_Prototype8 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 57.40%
# Accuracy, Training: 63.16%
# Accuracy, Testing: 55.91%
# ###################################################
# Brier Skill Score (Test): 0.0358
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5918
# Precision Accuracy Score (Test): 0.5655
# F1 Score (Test): 0.5770
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5249
# Precision Accuracy Score (Train): 0.6527
# F1 Score (Test): 0.5370
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 39.58%
# Average Num. of 10% Confident and Correct Negative Predictions: 33.51%
# Average Num. of 10% Confident and FALSE Postive Predictions: 10.43%
# Average Num. of 10% Confident and FALSE Negative Predictions: 16.48%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 73.09%
# Average Num. of 10% Confident and FALSE Predictions: 26.91%
#
#
# Trying SHAP ...
# Done.
# _____________________________________

# %% [markdown]
# ### Canada

# %%
##Loop through regions and files to do feature selection.
files = ['Canada_ERA5','Canada_Prototype5','Canada_Prototype6','Canada_Prototype7','Canada_Prototype8']

for j in range(len(files)):
    print(f'Working on {str(files[j])} ...')

    input2 = testing_data(prototype[j])
    #eur_input1 = input1[input1.columns[nova_feats[j]]]
    #eur_input2 = input2[input2.columns[nova_feats[j]]]
    ##commenting out feature selection just to test how that affects the model ...
    eur_input1 = input1
    eur_input2 = input2

    ##CONSTANT ERA5 OUTPUT
    infile = open(f'./new_data/2classtemps_Canada_ERA5.p',"rb",)
    ERA5_temp = pickle.load(infile) 
    infile.close()
    
    eur_test90, eur_fulltest, eur_shap_obj, eur_posXtest, eur_FposXtest, eur_negXtest, eur_FnegXtest, acc_reg2_test, acc_reg3_test, acc_reg4_test = rf_90thpercentile(n,shift, idx, eur_input1, eur_input2, ERA5_temp, 'nova',files[j])
    #____________________________________________________#
    #plot SHAP
    plt.title(f'SHAP Values for Negative Canadian Temp Anomalies, {str(files[j])}',fontsize =14, y = 1.05)
    ax = shap.plots.beeswarm(eur_shap_obj[:,:,0], show = False) ##for negative classifications ... this is physically consistent!
    plt.tight_layout()
    plt.savefig(f'./images/{str(prototype[j])}/All_SHAP_{str(files[j])}.png')
    plt.close()
    #____________________________________________________#
    #plot ACC
    bins = np.linspace(0.4, 1,13)  # 10 bins from 0.4 to 1
    ##bin the testing 90th percentile accuracy data
    counts90, edges90 = np.histogram(eur_test90, bins=bins)
    countsfull, edgesfull = np.histogram(eur_fulltest, bins=bins)
    counts_era5, edges_era5= np.histogram(acc_reg3_test, bins=bins) ##relative to ERA5 truth
    #plot the full dataset
    #offset = 0.02  # Adjust this value if needed for better visibility
    plt.bar(edgesfull[:-1], countsfull, width=np.diff(edgesfull), 
            edgecolor='black', alpha=0.5, label='All Predictions', align='edge', color='blue')
    
    #plot the 90th percentile
    plt.bar(edges90[:-1], counts90, width=np.diff(edges90), 
            edgecolor='black', alpha=0.5, label='>90th Percentile Predictions', align='edge', color = 'lightblue')
    
    #plot the ERA-5 comparison
    plt.bar(edges_era5[:-1], counts_era5, width=np.diff(edges_era5), 
            edgecolor='black', alpha=0.5, label='Predictions vs. ERA-5 Truth', align='edge', color = 'indigo')
    
    plt.xlabel('Accuracy',fontsize =14)
    plt.ylabel('Number of Models',fontsize =14)
    plt.ylim(0,105)
    plt.legend()
    plt.title(f'Testing ACCs for 100 CVs, {str(files[j])}',fontsize =12)
    plt.tight_layout()
    plt.savefig(f'./images/{str(prototype[j])}/All_ACC_{str(files[j])}.png')
    plt.close()
    print('_____________________________________')
    #____________________________________________________#
    ##export out files to make the next few plots w/o normalization
    pickle.dump(eur_posXtest, open(f'./index/All_pos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FposXtest, open(f'./index/All_Fpos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_negXtest, open(f'./index/All_neg_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FnegXtest, open(f'./index/All_Fneg_{str(files[j])}.p', 'wb'))
# Out:
# Working on Canada_ERA5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 70.62%
# Accuracy, Training: 72.21%
# Accuracy, Testing: 75.33%
# ###################################################
# Brier Skill Score (Test): 0.1737
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.8736
# Precision Accuracy Score (Test): 0.7551
# F1 Score (Test): 0.8097
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5713
# Precision Accuracy Score (Train): 0.7764
# F1 Score (Test): 0.6483
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 44.35%
# Average Num. of 10% Confident and Correct Negative Predictions: 31.42%
# Average Num. of 10% Confident and FALSE Postive Predictions: 5.65%
# Average Num. of 10% Confident and FALSE Negative Predictions: 18.58%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 75.77%
# Average Num. of 10% Confident and FALSE Predictions: 24.23%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Canada_Prototype5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 70.97%
# Accuracy, Training: 72.11%
# Accuracy, Testing: 66.10%
# ###################################################
# Brier Skill Score (Test): 0.0958
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.8705
# Precision Accuracy Score (Test): 0.6114
# F1 Score (Test): 0.7180
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.4546
# Precision Accuracy Score (Train): 0.7757
# F1 Score (Test): 0.5743
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 46.91%
# Average Num. of 10% Confident and Correct Negative Predictions: 32.82%
# Average Num. of 10% Confident and FALSE Postive Predictions: 3.06%
# Average Num. of 10% Confident and FALSE Negative Predictions: 17.20%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 79.73%
# Average Num. of 10% Confident and FALSE Predictions: 20.27%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Canada_Prototype6 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 70.99%
# Accuracy, Training: 72.11%
# Accuracy, Testing: 72.55%
# ###################################################
# Brier Skill Score (Test): 0.1760
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.8958
# Precision Accuracy Score (Test): 0.6978
# F1 Score (Test): 0.7843
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5113
# Precision Accuracy Score (Train): 0.7750
# F1 Score (Test): 0.6221
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 46.84%
# Average Num. of 10% Confident and Correct Negative Predictions: 38.57%
# Average Num. of 10% Confident and FALSE Postive Predictions: 3.14%
# Average Num. of 10% Confident and FALSE Negative Predictions: 11.45%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 85.41%
# Average Num. of 10% Confident and FALSE Predictions: 14.59%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Canada_Prototype7 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 70.99%
# Accuracy, Training: 72.14%
# Accuracy, Testing: 70.73%
# ###################################################
# Brier Skill Score (Test): 0.1407
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.9002
# Precision Accuracy Score (Test): 0.6507
# F1 Score (Test): 0.7551
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5131
# Precision Accuracy Score (Train): 0.7756
# F1 Score (Test): 0.6358
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 48.30%
# Average Num. of 10% Confident and Correct Negative Predictions: 40.39%
# Average Num. of 10% Confident and FALSE Postive Predictions: 1.68%
# Average Num. of 10% Confident and FALSE Negative Predictions: 9.63%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 88.69%
# Average Num. of 10% Confident and FALSE Predictions: 11.31%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Canada_Prototype8 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 70.79%
# Accuracy, Training: 72.14%
# Accuracy, Testing: 67.54%
# ###################################################
# Brier Skill Score (Test): 0.1449
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.8485
# Precision Accuracy Score (Test): 0.6462
# F1 Score (Test): 0.7334
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.4826
# Precision Accuracy Score (Train): 0.7758
# F1 Score (Test): 0.5843
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 42.93%
# Average Num. of 10% Confident and Correct Negative Predictions: 44.74%
# Average Num. of 10% Confident and FALSE Postive Predictions: 7.06%
# Average Num. of 10% Confident and FALSE Negative Predictions: 5.27%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 87.67%
# Average Num. of 10% Confident and FALSE Predictions: 12.33%
#
#
# Trying SHAP ...
# Done.
# _____________________________________

# %% [markdown]
# ### SEUS

# %%
##Loop through regions and files to do feature selection.
files = ['SEUS_ERA5','SEUS_Prototype5','SEUS_Prototype6','SEUS_Prototype7','SEUS_Prototype8']

for j in range(len(files)):
    print(f'Working on {str(files[j])} ...')
    
    input2 = testing_data(prototype[j])
    #eur_input1 = input1[input1.columns[seus_feats[j]]]
    #eur_input2 = input2[input2.columns[seus_feats[j]]]
    ##commenting out feature selection just to test how that affects the model ...
    eur_input1 = input1
    eur_input2 = input2

    ##CONSTANT ERA5 OUTPUT
    infile = open(f'./new_data/2classtemps_SEUS_ERA5.p',"rb",)
    ERA5_temp = pickle.load(infile) 
    infile.close()
    
    eur_test90, eur_fulltest, eur_shap_obj, eur_posXtest, eur_FposXtest, eur_negXtest, eur_FnegXtest, acc_reg2_test, acc_reg3_test, acc_reg4_test = rf_90thpercentile(n,shift, idx, eur_input1, eur_input2, ERA5_temp, 'seus', files[j])
    #____________________________________________________#
    #plot SHAP
    plt.title(f'SHAP Values for SEUS Temp Anomalies, {str(files[j])}',fontsize =14, y = 1.05)
    ax = shap.plots.beeswarm(eur_shap_obj[:,:,0], show = False) ##for negative classifications ... this is physically consistent!
    plt.tight_layout()
    plt.savefig(f'./images/{str(prototype[j])}/All_SHAP_{str(files[j])}.png')
    plt.close()
    #____________________________________________________#
    #plot ACC
    bins = np.linspace(0.4, 1,13)  # 10 bins from 0.4 to 1
    ##bin the testing 90th percentile accuracy data
    counts90, edges90 = np.histogram(eur_test90, bins=bins)
    countsfull, edgesfull = np.histogram(eur_fulltest, bins=bins)
    counts_era5, edges_era5= np.histogram(acc_reg3_test, bins=bins) ##relative to ERA5 truth
    #plot the full dataset
    #offset = 0.02  # Adjust this value if needed for better visibility
    plt.bar(edgesfull[:-1], countsfull, width=np.diff(edgesfull), 
            edgecolor='black', alpha=0.5, label='All Predictions', align='edge', color='blue')
    
    #plot the 90th percentile
    plt.bar(edges90[:-1], counts90, width=np.diff(edges90), 
            edgecolor='black', alpha=0.5, label='>90th Percentile Predictions', align='edge', color = 'lightblue')
    
    #plot the ERA-5 comparison
    plt.bar(edges_era5[:-1], counts_era5, width=np.diff(edges_era5), 
            edgecolor='black', alpha=0.5, label='Predictions vs. ERA-5 Truth', align='edge', color = 'indigo')
    
    plt.xlabel('Accuracy',fontsize =14)
    plt.ylabel('Number of Models',fontsize =14)
    plt.ylim(0,105)
    plt.legend()
    plt.title(f'Testing ACCs for 100 CVs, {str(files[j])}',fontsize =12)
    plt.tight_layout()
    plt.savefig(f'./images/{str(prototype[j])}/All_ACC_{str(files[j])}.png')
    plt.close()
    print('_____________________________________')
    #____________________________________________________#
     ##export out files to make the next few plots w/o normalization
    pickle.dump(eur_posXtest, open(f'./index/All_pos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FposXtest, open(f'./index/All_Fpos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_negXtest, open(f'./index/All_neg_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FnegXtest, open(f'./index/All_Fneg_{str(files[j])}.p', 'wb'))
# Out:
# Working on SEUS_ERA5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 62.25%
# Accuracy, Training: 63.17%
# Accuracy, Testing: 59.06%
# ###################################################
# Brier Skill Score (Test): 0.0101
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5771
# Precision Accuracy Score (Test): 0.6558
# F1 Score (Test): 0.6120
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.6080
# Precision Accuracy Score (Train): 0.6253
# F1 Score (Test): 0.5637
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 29.90%
# Average Num. of 10% Confident and Correct Negative Predictions: 32.54%
# Average Num. of 10% Confident and FALSE Postive Predictions: 20.11%
# Average Num. of 10% Confident and FALSE Negative Predictions: 17.45%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 62.44%
# Average Num. of 10% Confident and FALSE Predictions: 37.56%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on SEUS_Prototype5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 62.29%
# Accuracy, Training: 63.17%
# Accuracy, Testing: 58.07%
# ###################################################
# Brier Skill Score (Test): 0.0313
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5725
# Precision Accuracy Score (Test): 0.5331
# F1 Score (Test): 0.5512
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5874
# Precision Accuracy Score (Train): 0.6259
# F1 Score (Test): 0.6054
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 31.97%
# Average Num. of 10% Confident and Correct Negative Predictions: 33.95%
# Average Num. of 10% Confident and FALSE Postive Predictions: 18.02%
# Average Num. of 10% Confident and FALSE Negative Predictions: 16.06%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 65.92%
# Average Num. of 10% Confident and FALSE Predictions: 34.08%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on SEUS_Prototype6 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 62.12%
# Accuracy, Training: 63.22%
# Accuracy, Testing: 61.54%
# ###################################################
# Brier Skill Score (Test): 0.0516
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5961
# Precision Accuracy Score (Test): 0.6211
# F1 Score (Test): 0.6074
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.6349
# Precision Accuracy Score (Train): 0.6269
# F1 Score (Test): 0.6221
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 34.07%
# Average Num. of 10% Confident and Correct Negative Predictions: 27.48%
# Average Num. of 10% Confident and FALSE Postive Predictions: 15.92%
# Average Num. of 10% Confident and FALSE Negative Predictions: 22.53%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 61.55%
# Average Num. of 10% Confident and FALSE Predictions: 38.45%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on SEUS_Prototype7 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 61.61%
# Accuracy, Training: 63.32%
# Accuracy, Testing: 60.24%
# ###################################################
# Brier Skill Score (Test): 0.0474
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5412
# Precision Accuracy Score (Test): 0.5712
# F1 Score (Test): 0.5537
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.6543
# Precision Accuracy Score (Train): 0.6274
# F1 Score (Test): 0.6397
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 31.37%
# Average Num. of 10% Confident and Correct Negative Predictions: 34.80%
# Average Num. of 10% Confident and FALSE Postive Predictions: 18.62%
# Average Num. of 10% Confident and FALSE Negative Predictions: 15.20%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 66.18%
# Average Num. of 10% Confident and FALSE Predictions: 33.82%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on SEUS_Prototype8 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 62.02%
# Accuracy, Training: 63.23%
# Accuracy, Testing: 55.12%
# ###################################################
# Brier Skill Score (Test): -0.0090
# ###################################################
# Recall and Precision: Neg Cat
# ______________________________
# Recall Accuracy Score (Test): 0.4996
# Precision Accuracy Score (Test): 0.5372
# F1 Score (Test): 0.5163
# ###################################################
# Recall and Precision: Pos Cat
# ______________________________
# Recall Accuracy Score (Test): 0.5994
# Precision Accuracy Score (Train): 0.6266
# F1 Score (Test): 0.5798
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 28.08%
# Average Num. of 10% Confident and Correct Negative Predictions: 27.10%
# Average Num. of 10% Confident and FALSE Postive Predictions: 21.92%
# Average Num. of 10% Confident and FALSE Negative Predictions: 22.91%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 55.17%
# Average Num. of 10% Confident and FALSE Predictions: 44.83%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
