# %% [markdown]
# ### Random Forests at 14-days leadtime for all regions.
#
# File generated 9/18/2025 for Chapter 4 of Dissertation.
# Modified 12/8/2025 for use in reduced UFS analysis.
#
# This file utilizes definition statements containing RF architecture to create three separate RF models, each for a designated forecast region.
#
# Forecast leadtime can be changed as needed.

# %%
##just to stop the excess number of warnings 
import warnings
warnings.filterwarnings('ignore')

#relevant import statements
import numpy as np
import math
import pandas as pd
import xarray as xr 
import pickle 
import matplotlib.pyplot as plt

import random
from random import seed
from random import randint
from random import sample

import seaborn as sns # statistical data visualization
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.feature_selection import SelectFromModel

import keras
import shap
# Out:
# 2025-12-08 16:37:01.395311: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-08 16:37:01.440354: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-12-08 16:37:01.440387: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-12-08 16:37:01.441515: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-12-08 16:37:01.450731: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-08 16:37:03.050756: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#import definitions 
from SkillStats_MOD import BSS, RAS, PAS

from RF_archMOD import rf_featselect,rf_90thpercentile

# %% [markdown]
# I am going to do a modified version of the architecture def here because I have to change the dataset structure.
#
# Start with bringing in the old data for training/validation.

# %%
#load OG input data, it is max/min standardized, NaNs removed
#stratospheric polar vortex ellipse diagnostics from Fernandez et al 2025 (in review)
infile = open("../old_data/nolag_extendedanom_input.p", 'rb') 
nolag_input = pickle.load(infile)
infile.close()

nolag_input.shape
# Out:
# (62, 149, 8)

# %% [markdown]
# The input data stays the same regardless of forecast region.
#
# The original array starts on October 19th. The shift send this forward to November 2nd.

# %%
idx = 135 #129 for 20, 119 for 30.
inp1 = np.empty((52,idx,7)) #cnew input array, 14 day lag. 
shift = 14

##reshaping to change lag in metrics for input
inp1[:,:,0] = nolag_input[:52,shift:,0] ##wind
inp1[:,:,1] = nolag_input[:52,shift:,1] ##ratio
inp1[:,:,2] = nolag_input[:52,shift:,2] ##latitude
inp1[:,:,3] = nolag_input[:52,shift:,3] ##longitude
inp1[:,:,4] = nolag_input[:52,shift:,4] ##size
inp1[:,:,5] = nolag_input[:52,shift:,5] ##ephi
inp1[:,:,6] = nolag_input[:52,shift:,6] ##gph

inp = inp1.reshape(52*idx,7)

#convert to pandas dataframe
input1 = pd.DataFrame(inp)
#label columns of variables for input data
col_names = ['wind','rat','cenlat','cenlon','size','ephi','gph']
input1.columns = col_names

# %%
def testing_data(p):
    infile = open(f'./new_data/input_{str(p)}.p', 'rb') 
    testing_input = pickle.load(infile)
    infile.close()
    
    inp = testing_input.reshape(56*10,7)
    
    #convert to pandas dataframe
    input2 = pd.DataFrame(inp)
    #label columns of variables for input data
    col_names = ['wind','rat','cenlat','cenlon','size','ephi','gph']
    input2.columns = col_names
    return input2

# %% [markdown]
# ### Begin RF Feature selection test.

# %%
def feat_imp_plot(important,input1,files):
    imp = np.nanmean(important, axis = 0)
    imp.shape
    
    #plot features by relative importance
    indices = np.argsort(imp)[::-1]  #sort by importance
    c = ["navy","royalblue","slateblue","blueviolet","darkviolet","purple","mediumvioletred","magenta"]
    
    plt.figure(figsize=(9, 6))
    plt.title(f'Average Feature Importances Across 100 CVs, {str(files)}',fontsize =18)
    plt.barh(range(input1.shape[1]), imp[indices], align="center", color = c)
    plt.yticks(range(input1.shape[1]), input1.columns[indices],fontsize =14)
    plt.xticks(fontsize =14)
    plt.xlabel("Relative Importance",fontsize =16)
    plt.gca().invert_yaxis()
    plt.savefig(f'./images/FeatureImportance_{str(files)}.png',bbox_inches = 'tight')

# %%
#number of cross validations
n = 100

regions = ['eur','nova','seus']

# %%
##Loop through regions and files to do feature selection.
for i in range(len(regions)):
    ##EUROPE
    if regions[i] == 'eur':
        files = ['Europe_ERA5','Europe_Prototype5','Europe_Prototype6','Europe_Prototype7','Europe_Ptotype8']
        prototype = ['ERA5','Prototype5','Prototype6','Prototype7','Prototype8']
        for j in range(len(files)):
            print(f'Working on {str(files[j])} ...')
            input2 = testing_data(prototype[j])
            eur_important = rf_featselect(n,shift,idx,input1,input2,regions[i],files[j])
            feat_imp_plot(eur_important,input1,files[j])
            print('_____________________________________')
    ##CANADA
    if regions[i] == 'nova':
        files = ['Canada_ERA5','Canada_Prototype5','Canada_Prototype6','Canada_Prototype7','Canada_Prototype8']
        prototype = ['ERA5','Prototype5','Prototype6','Prototype7','Prototype8']
        for j in range(len(files)):
            print(f'Working on {str(files[j])} ...')
            input2 = testing_data(prototype[j])
            can_important = rf_featselect(n,shift,idx,input1,input2,regions[i],files[j])
            feat_imp_plot(can_important,input1,files[j])
            print('_____________________________________')
    ##SEUS
    if regions[i] == 'seus':
        files = ['SEUS_ERA5','SEUS_Prototype5','SEUS_Prototype6','SEUS_Prototype7','SEUS_Prototype8']
        prototype = ['ERA5','Prototype5','Prototype6','Prototype7','Prototype8']
        for j in range(len(files)):
            print(f'Working on {str(files[j])} ...')
            input2 = testing_data(prototype[j])
            seus_important = rf_featselect(n,shift,idx,input1,input2,regions[i],files[j])
            feat_imp_plot(seus_important,input1,files[j])
            print('_____________________________________')
# Out:
# Working on Europe_ERA5 ...
# Begin CV ...

# %% [markdown]
# ## Second RF run post feature selection

# %% [markdown]
# ### Europe

# %%
##Loop through regions and files to do feature selection.
prototype = ['ERA5','Prototype5','Prototype6','Prototype7','Prototype8']
####################
files = ['Europe_ERA5','Europe_Prototype5','Europe_Prototype6','Europe_Prototype7','Europe_Prototype8']

for j in range(len(files)):
    print(f'Working on {str(files[j])} ...')
    ##select prototype testing data ...
    input2 = testing_data(prototype[j])
    
    eur_input1 = input1[["wind","cenlon","cenlat","gph"]]
    eur_input2 = input2[["wind","cenlon","cenlat","gph"]]
  
    ##CONSTANT ERA5 OUTPUT
    infile = open(f'./new_data/2classtemps_Europe_ERA5.p',"rb",)
    ERA5_temp = pickle.load(infile) 
    infile.close()

    eur_test90, eur_fulltest, eur_shap_obj, eur_posXtest, eur_FposXtest, eur_negXtest, eur_FnegXtest, acc_reg2_test, acc_reg3_test, acc_reg4_test = rf_90thpercentile(n,shift, idx, eur_input1, eur_input2, ERA5_temp, 'eur', files[j])
    #____________________________________________________#
    #plot SHAP
    plt.title(f'SHAP Values for Negative Europe Temp Anomalies, {str(files[j])}',fontsize =14, y = 1.05)
    ax = shap.plots.beeswarm(eur_shap_obj[:,:,0], show = False) ##for negative classifications ... this is physically consistent!
    plt.tight_layout()
    plt.savefig(f'./images/SHAP_{str(files[j])}.png')
    plt.close()
    #____________________________________________________#
    #plot ACC
    bins = np.linspace(0.4, 1,13)  # 10 bins from 0.4 to 1
    ##bin the testing 90th percentile accuracy data
    counts90, edges90 = np.histogram(eur_test90, bins=bins)
    countsfull, edgesfull = np.histogram(eur_fulltest, bins=bins)
    counts_era5, edges_era5= np.histogram(acc_reg3_test, bins=bins) ##relative to ERA5 truth
    #plot the full dataset
    #offset = 0.02  # Adjust this value if needed for better visibility
    plt.bar(edgesfull[:-1], countsfull, width=np.diff(edgesfull), 
            edgecolor='black', alpha=0.5, label='All Predictions', align='edge', color='blue')
    
    #plot the 90th percentile
    plt.bar(edges90[:-1], counts90, width=np.diff(edges90), 
            edgecolor='black', alpha=0.5, label='>90th Percentile Predictions', align='edge', color = 'lightblue')
    
    #plot the ERA-5 comparison
    plt.bar(edges_era5[:-1], counts_era5, width=np.diff(edges_era5), 
            edgecolor='black', alpha=0.5, label='Predictions vs. ERA-5 Truth', align='edge', color = 'indigo')
    
    plt.xlabel('Accuracy',fontsize =14)
    plt.ylabel('Number of Models',fontsize =14)
    plt.legend()
    plt.title(f'Testing ACCs for 100 CVs, {str(files[j])}',fontsize =12)
    plt.tight_layout()
    plt.savefig(f'./images/ACC_{str(files[j])}.png')
    plt.close()
    print('_____________________________________')
    #____________________________________________________#
    ##export out files to make the next few plots w/o normalization
    pickle.dump(eur_posXtest, open(f'./index/pos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FposXtest, open(f'./index/Fpos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_negXtest, open(f'./index/neg_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FnegXtest, open(f'./index/Fneg_{str(files[j])}.p', 'wb'))
# Out:
# Working on Europe_ERA5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 58.05%
# Accuracy, Training: 61.95%
# Accuracy, Testing: 58.77%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0701
# Brier Skill Score (Test): 0.0426
# Brier Skill Score (Validation): 0.0247
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7482
# Recall Accuracy Score (Test): 0.7754
# Recall AccuracyScore (Validation): 0.7234
# Precision Accuracy Score (Train): 0.6101
# Precision Accuracy Score (Test): 0.5620
# Precision AccuracyScore (Validation): 0.5755
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.4792
# Recall Accuracy Score (Test): 0.4029
# Recall AccuracyScore (Validation): 0.4301
# Precision Accuracy Score (Train): 0.6376
# Precision Accuracy Score (Test): 0.6463
# Precision AccuracyScore (Validation): 0.5950
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 38.15%
# Average Num. of 10% Confident and Correct Negative Predictions: 29.75%
# Average Num. of 10% Confident and FALSE Postive Predictions: 11.84%
# Average Num. of 10% Confident and FALSE Negative Predictions: 20.26%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 67.90%
# Average Num. of 10% Confident and FALSE Predictions: 32.10%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Europe_Prototype5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 57.85%
# Accuracy, Training: 62.01%
# Accuracy, Testing: 60.52%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0712
# Brier Skill Score (Test): 0.0604
# Brier Skill Score (Validation): 0.0227
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7533
# Recall Accuracy Score (Test): 0.8274
# Recall AccuracyScore (Validation): 0.7214
# Precision Accuracy Score (Train): 0.6093
# Precision Accuracy Score (Test): 0.5490
# Precision AccuracyScore (Validation): 0.5758
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.4752
# Recall Accuracy Score (Test): 0.4149
# Recall AccuracyScore (Validation): 0.4264
# Precision Accuracy Score (Train): 0.6410
# Precision Accuracy Score (Test): 0.7383
# Precision AccuracyScore (Validation): 0.5884
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 45.19%
# Average Num. of 10% Confident and Correct Negative Predictions: 28.27%
# Average Num. of 10% Confident and FALSE Postive Predictions: 4.81%
# Average Num. of 10% Confident and FALSE Negative Predictions: 21.73%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 73.46%
# Average Num. of 10% Confident and FALSE Predictions: 26.54%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Europe_Prototype6 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 57.36%
# Accuracy, Training: 62.00%
# Accuracy, Testing: 55.15%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0710
# Brier Skill Score (Test): 0.0144
# Brier Skill Score (Validation): 0.0238
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7583
# Recall Accuracy Score (Test): 0.7682
# Recall AccuracyScore (Validation): 0.7297
# Precision Accuracy Score (Train): 0.6088
# Precision Accuracy Score (Test): 0.5210
# Precision AccuracyScore (Validation): 0.5686
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.4696
# Recall Accuracy Score (Test): 0.3546
# Recall AccuracyScore (Validation): 0.4076
# Precision Accuracy Score (Train): 0.6421
# Precision Accuracy Score (Test): 0.6250
# Precision AccuracyScore (Validation): 0.5870
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 34.84%
# Average Num. of 10% Confident and Correct Negative Predictions: 29.59%
# Average Num. of 10% Confident and FALSE Postive Predictions: 15.15%
# Average Num. of 10% Confident and FALSE Negative Predictions: 20.41%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 64.43%
# Average Num. of 10% Confident and FALSE Predictions: 35.57%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Europe_Prototype7 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 57.73%
# Accuracy, Training: 62.05%
# Accuracy, Testing: 56.81%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0720
# Brier Skill Score (Test): 0.0310
# Brier Skill Score (Validation): 0.0195
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7545
# Recall Accuracy Score (Test): 0.7604
# Recall AccuracyScore (Validation): 0.7111
# Precision Accuracy Score (Train): 0.6090
# Precision Accuracy Score (Test): 0.5505
# Precision AccuracyScore (Validation): 0.5782
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.4754
# Recall Accuracy Score (Test): 0.3749
# Recall AccuracyScore (Validation): 0.4331
# Precision Accuracy Score (Train): 0.6428
# Precision Accuracy Score (Test): 0.6100
# Precision AccuracyScore (Validation): 0.5807
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 38.83%
# Average Num. of 10% Confident and Correct Negative Predictions: 29.07%
# Average Num. of 10% Confident and FALSE Postive Predictions: 11.17%
# Average Num. of 10% Confident and FALSE Negative Predictions: 20.93%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 67.91%
# Average Num. of 10% Confident and FALSE Predictions: 32.09%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Europe_Prototype8 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 57.56%
# Accuracy, Training: 62.02%
# Accuracy, Testing: 51.66%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0705
# Brier Skill Score (Test): -0.0254
# Brier Skill Score (Validation): 0.0229
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7478
# Recall Accuracy Score (Test): 0.7032
# Recall AccuracyScore (Validation): 0.7144
# Precision Accuracy Score (Train): 0.6111
# Precision Accuracy Score (Test): 0.5034
# Precision AccuracyScore (Validation): 0.5706
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.4809
# Recall Accuracy Score (Test): 0.3394
# Recall AccuracyScore (Validation): 0.4300
# Precision Accuracy Score (Train): 0.6374
# Precision Accuracy Score (Test): 0.5441
# Precision AccuracyScore (Validation): 0.5892
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 30.17%
# Average Num. of 10% Confident and Correct Negative Predictions: 27.44%
# Average Num. of 10% Confident and FALSE Postive Predictions: 19.84%
# Average Num. of 10% Confident and FALSE Negative Predictions: 22.56%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 57.61%
# Average Num. of 10% Confident and FALSE Predictions: 42.39%
#
#
# Trying SHAP ...
# Done.
# _____________________________________

# %% [markdown]
# ### Canada

# %%
##Loop through regions and files to do feature selection.
files = ['Canada_ERA5','Canada_Prototype5','Canada_Prototype6','Canada_Prototype7','Canada_Prototype8']

for j in range(len(files)):
    print(f'Working on {str(files[j])} ...')

    input2 = testing_data(prototype[j])
    eur_input1 = input1[["wind","cenlon","cenlat","gph"]]
    eur_input2 = input2[["wind","cenlon","cenlat","gph"]]

    ##CONSTANT ERA5 OUTPUT
    infile = open(f'./new_data/2classtemps_Canada_ERA5.p',"rb",)
    ERA5_temp = pickle.load(infile) 
    infile.close()
    
    eur_test90, eur_fulltest, eur_shap_obj, eur_posXtest, eur_FposXtest, eur_negXtest, eur_FnegXtest, acc_reg2_test, acc_reg3_test, acc_reg4_test = rf_90thpercentile(n,shift, idx, eur_input1, eur_input2, ERA5_temp, 'nova',files[j])
    #____________________________________________________#
    #plot SHAP
    plt.title(f'SHAP Values for Negative Canadian Temp Anomalies, {str(files[j])}',fontsize =14, y = 1.05)
    ax = shap.plots.beeswarm(eur_shap_obj[:,:,0], show = False) ##for negative classifications ... this is physically consistent!
    plt.tight_layout()
    plt.savefig(f'./images/SHAP_{str(files[j])}.png')
    plt.close()
    #____________________________________________________#
    #plot ACC
    bins = np.linspace(0.4, 1,13)  # 10 bins from 0.4 to 1
    ##bin the testing 90th percentile accuracy data
    counts90, edges90 = np.histogram(eur_test90, bins=bins)
    countsfull, edgesfull = np.histogram(eur_fulltest, bins=bins)
    counts_era5, edges_era5= np.histogram(acc_reg3_test, bins=bins) ##relative to ERA5 truth
    #plot the full dataset
    #offset = 0.02  # Adjust this value if needed for better visibility
    plt.bar(edgesfull[:-1], countsfull, width=np.diff(edgesfull), 
            edgecolor='black', alpha=0.5, label='All Predictions', align='edge', color='blue')
    
    #plot the 90th percentile
    plt.bar(edges90[:-1], counts90, width=np.diff(edges90), 
            edgecolor='black', alpha=0.5, label='>90th Percentile Predictions', align='edge', color = 'lightblue')
    
    #plot the ERA-5 comparison
    plt.bar(edges_era5[:-1], counts_era5, width=np.diff(edges_era5), 
            edgecolor='black', alpha=0.5, label='Predictions vs. ERA-5 Truth', align='edge', color = 'indigo')
    
    plt.xlabel('Accuracy',fontsize =14)
    plt.ylabel('Number of Models',fontsize =14)
    plt.legend()
    plt.title(f'Testing ACCs for 100 CVs, {str(files[j])}',fontsize =12)
    plt.tight_layout()
    plt.savefig(f'./images/ACC_{str(files[j])}.png')
    plt.close()
    print('_____________________________________')
    #____________________________________________________#
    ##export out files to make the next few plots w/o normalization
    pickle.dump(eur_posXtest, open(f'./index/pos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FposXtest, open(f'./index/Fpos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_negXtest, open(f'./index/neg_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FnegXtest, open(f'./index/Fneg_{str(files[j])}.p', 'wb'))
# Out:
# Working on Canada_ERA5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 70.38%
# Accuracy, Training: 71.96%
# Accuracy, Testing: 75.53%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.2194
# Brier Skill Score (Test): 0.2057
# Brier Skill Score (Validation): 0.1785
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.8748
# Recall Accuracy Score (Test): 0.8772
# Recall AccuracyScore (Validation): 0.8614
# Precision Accuracy Score (Train): 0.7047
# Precision Accuracy Score (Test): 0.7542
# Precision AccuracyScore (Validation): 0.6979
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5138
# Recall Accuracy Score (Test): 0.5739
# Recall AccuracyScore (Validation): 0.4891
# Precision Accuracy Score (Train): 0.7560
# Precision Accuracy Score (Test): 0.7616
# Precision AccuracyScore (Validation): 0.7202
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 42.76%
# Average Num. of 10% Confident and Correct Negative Predictions: 34.40%
# Average Num. of 10% Confident and FALSE Postive Predictions: 7.24%
# Average Num. of 10% Confident and FALSE Negative Predictions: 15.60%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 77.16%
# Average Num. of 10% Confident and FALSE Predictions: 22.84%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Canada_Prototype5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 70.13%
# Accuracy, Training: 72.03%
# Accuracy, Testing: 69.38%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.2205
# Brier Skill Score (Test): 0.1657
# Brier Skill Score (Validation): 0.1754
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.8769
# Recall Accuracy Score (Test): 0.8847
# Recall AccuracyScore (Validation): 0.8621
# Precision Accuracy Score (Train): 0.7049
# Precision Accuracy Score (Test): 0.6483
# Precision AccuracyScore (Validation): 0.6946
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5123
# Recall Accuracy Score (Test): 0.4919
# Recall AccuracyScore (Validation): 0.4842
# Precision Accuracy Score (Train): 0.7582
# Precision Accuracy Score (Test): 0.8041
# Precision AccuracyScore (Validation): 0.7209
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 46.16%
# Average Num. of 10% Confident and Correct Negative Predictions: 34.56%
# Average Num. of 10% Confident and FALSE Postive Predictions: 3.84%
# Average Num. of 10% Confident and FALSE Negative Predictions: 15.43%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 80.73%
# Average Num. of 10% Confident and FALSE Predictions: 19.27%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Canada_Prototype6 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 69.92%
# Accuracy, Training: 72.05%
# Accuracy, Testing: 69.09%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.2214
# Brier Skill Score (Test): 0.1738
# Brier Skill Score (Validation): 0.1717
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.8748
# Recall Accuracy Score (Test): 0.8603
# Recall AccuracyScore (Validation): 0.8620
# Precision Accuracy Score (Train): 0.7060
# Precision Accuracy Score (Test): 0.6619
# Precision AccuracyScore (Validation): 0.6915
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5151
# Recall Accuracy Score (Test): 0.4970
# Recall AccuracyScore (Validation): 0.4807
# Precision Accuracy Score (Train): 0.7557
# Precision Accuracy Score (Test): 0.7606
# Precision AccuracyScore (Validation): 0.7208
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 48.55%
# Average Num. of 10% Confident and Correct Negative Predictions: 34.22%
# Average Num. of 10% Confident and FALSE Postive Predictions: 1.41%
# Average Num. of 10% Confident and FALSE Negative Predictions: 15.82%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 82.77%
# Average Num. of 10% Confident and FALSE Predictions: 17.23%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Canada_Prototype7 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 70.26%
# Accuracy, Training: 71.99%
# Accuracy, Testing: 70.37%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.2203
# Brier Skill Score (Test): 0.1814
# Brier Skill Score (Validation): 0.1778
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.8759
# Recall Accuracy Score (Test): 0.8946
# Recall AccuracyScore (Validation): 0.8611
# Precision Accuracy Score (Train): 0.7051
# Precision Accuracy Score (Test): 0.6542
# Precision AccuracyScore (Validation): 0.6949
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5123
# Recall Accuracy Score (Test): 0.5035
# Recall AccuracyScore (Validation): 0.4905
# Precision Accuracy Score (Train): 0.7563
# Precision Accuracy Score (Test): 0.8222
# Precision AccuracyScore (Validation): 0.7242
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 45.56%
# Average Num. of 10% Confident and Correct Negative Predictions: 41.05%
# Average Num. of 10% Confident and FALSE Postive Predictions: 4.44%
# Average Num. of 10% Confident and FALSE Negative Predictions: 8.96%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 86.60%
# Average Num. of 10% Confident and FALSE Predictions: 13.40%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Canada_Prototype8 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 70.41%
# Accuracy, Training: 71.98%
# Accuracy, Testing: 68.84%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.2196
# Brier Skill Score (Test): 0.1885
# Brier Skill Score (Validation): 0.1797
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.8766
# Recall Accuracy Score (Test): 0.8712
# Recall AccuracyScore (Validation): 0.8631
# Precision Accuracy Score (Train): 0.7045
# Precision Accuracy Score (Test): 0.6514
# Precision AccuracyScore (Validation): 0.6970
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5115
# Recall Accuracy Score (Test): 0.4883
# Recall AccuracyScore (Validation): 0.4896
# Precision Accuracy Score (Train): 0.7575
# Precision Accuracy Score (Test): 0.7783
# Precision AccuracyScore (Validation): 0.7250
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 46.95%
# Average Num. of 10% Confident and Correct Negative Predictions: 40.73%
# Average Num. of 10% Confident and FALSE Postive Predictions: 3.01%
# Average Num. of 10% Confident and FALSE Negative Predictions: 9.31%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 87.68%
# Average Num. of 10% Confident and FALSE Predictions: 12.32%
#
#
# Trying SHAP ...
# Done.
# _____________________________________

# %% [markdown]
# ### SEUS

# %%
##Loop through regions and files to do feature selection.
files = ['SEUS_ERA5','SEUS_Prototype5','SEUS_Prototype6','SEUS_Prototype7','SEUS_Prototype8']

for j in range(len(files)):
    print(f'Working on {str(files[j])} ...')
    
    input2 = testing_data(prototype[j])
    eur_input1 = input1[["wind","size","cenlat","gph"]]
    eur_input2 = input2[["wind","size","cenlat","gph"]]

    ##CONSTANT ERA5 OUTPUT
    infile = open(f'./new_data/2classtemps_SEUS_ERA5.p',"rb",)
    ERA5_temp = pickle.load(infile) 
    infile.close()
    
    eur_test90, eur_fulltest, eur_shap_obj, eur_posXtest, eur_FposXtest, eur_negXtest, eur_FnegXtest, acc_reg2_test, acc_reg3_test, acc_reg4_test = rf_90thpercentile(n,shift, idx, eur_input1, eur_input2, ERA5_temp, 'seus', files[j])
    #____________________________________________________#
    #plot SHAP
    plt.title(f'SHAP Values for SEUS Temp Anomalies, {str(files[j])}',fontsize =14, y = 1.05)
    ax = shap.plots.beeswarm(eur_shap_obj[:,:,0], show = False) ##for negative classifications ... this is physically consistent!
    plt.tight_layout()
    plt.savefig(f'./images/SHAP_{str(files[j])}.png')
    plt.close()
    #____________________________________________________#
    #plot ACC
    bins = np.linspace(0.4, 1,13)  # 10 bins from 0.4 to 1
    ##bin the testing 90th percentile accuracy data
    counts90, edges90 = np.histogram(eur_test90, bins=bins)
    countsfull, edgesfull = np.histogram(eur_fulltest, bins=bins)
    counts_era5, edges_era5= np.histogram(acc_reg3_test, bins=bins) ##relative to ERA5 truth
    #plot the full dataset
    #offset = 0.02  # Adjust this value if needed for better visibility
    plt.bar(edgesfull[:-1], countsfull, width=np.diff(edgesfull), 
            edgecolor='black', alpha=0.5, label='All Predictions', align='edge', color='blue')
    
    #plot the 90th percentile
    plt.bar(edges90[:-1], counts90, width=np.diff(edges90), 
            edgecolor='black', alpha=0.5, label='>90th Percentile Predictions', align='edge', color = 'lightblue')
    
    #plot the ERA-5 comparison
    plt.bar(edges_era5[:-1], counts_era5, width=np.diff(edges_era5), 
            edgecolor='black', alpha=0.5, label='Predictions vs. ERA-5 Truth', align='edge', color = 'indigo')
    
    plt.xlabel('Accuracy',fontsize =14)
    plt.ylabel('Number of Models',fontsize =14)
    plt.legend()
    plt.title(f'Testing ACCs for 100 CVs, {str(files[j])}',fontsize =12)
    plt.tight_layout()
    plt.savefig(f'./images/ACC_{str(files[j])}.png')
    plt.close()
    print('_____________________________________')
    #____________________________________________________#
     ##export out files to make the next few plots w/o normalization
    pickle.dump(eur_posXtest, open(f'./index/pos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FposXtest, open(f'./index/Fpos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_negXtest, open(f'./index/neg_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FnegXtest, open(f'./index/Fneg_{str(files[j])}.p', 'wb'))
# Out:
# Working on SEUS_ERA5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 61.45%
# Accuracy, Training: 63.19%
# Accuracy, Testing: 60.78%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0981
# Brier Skill Score (Test): 0.0439
# Brier Skill Score (Validation): 0.0658
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7076
# Recall Accuracy Score (Test): 0.7257
# Recall AccuracyScore (Validation): 0.6938
# Precision Accuracy Score (Train): 0.6267
# Precision Accuracy Score (Test): 0.6318
# Precision AccuracyScore (Validation): 0.6118
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5514
# Recall Accuracy Score (Test): 0.4561
# Recall AccuracyScore (Validation): 0.5297
# Precision Accuracy Score (Train): 0.6402
# Precision Accuracy Score (Test): 0.5641
# Precision AccuracyScore (Validation): 0.6195
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 30.12%
# Average Num. of 10% Confident and Correct Negative Predictions: 36.16%
# Average Num. of 10% Confident and FALSE Postive Predictions: 19.90%
# Average Num. of 10% Confident and FALSE Negative Predictions: 13.82%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 66.28%
# Average Num. of 10% Confident and FALSE Predictions: 33.72%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on SEUS_Prototype5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 61.57%
# Accuracy, Training: 63.29%
# Accuracy, Testing: 53.73%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0980
# Brier Skill Score (Test): 0.0091
# Brier Skill Score (Validation): 0.0658
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7122
# Recall Accuracy Score (Test): 0.6974
# Recall AccuracyScore (Validation): 0.7017
# Precision Accuracy Score (Train): 0.6268
# Precision Accuracy Score (Test): 0.5013
# Precision AccuracyScore (Validation): 0.6108
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5487
# Recall Accuracy Score (Test): 0.3986
# Recall AccuracyScore (Validation): 0.5237
# Precision Accuracy Score (Train): 0.6425
# Precision Accuracy Score (Test): 0.6034
# Precision AccuracyScore (Validation): 0.6236
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 38.41%
# Average Num. of 10% Confident and Correct Negative Predictions: 35.65%
# Average Num. of 10% Confident and FALSE Postive Predictions: 11.60%
# Average Num. of 10% Confident and FALSE Negative Predictions: 14.34%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 74.07%
# Average Num. of 10% Confident and FALSE Predictions: 25.93%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on SEUS_Prototype6 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 61.57%
# Accuracy, Training: 63.27%
# Accuracy, Testing: 62.32%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0982
# Brier Skill Score (Test): 0.0634
# Brier Skill Score (Validation): 0.0657
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7133
# Recall Accuracy Score (Test): 0.7718
# Recall AccuracyScore (Validation): 0.7033
# Precision Accuracy Score (Train): 0.6261
# Precision Accuracy Score (Test): 0.5923
# Precision AccuracyScore (Validation): 0.6114
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5472
# Recall Accuracy Score (Test): 0.4769
# Recall AccuracyScore (Validation): 0.5214
# Precision Accuracy Score (Train): 0.6429
# Precision Accuracy Score (Test): 0.6799
# Precision AccuracyScore (Validation): 0.6227
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 35.59%
# Average Num. of 10% Confident and Correct Negative Predictions: 30.67%
# Average Num. of 10% Confident and FALSE Postive Predictions: 14.41%
# Average Num. of 10% Confident and FALSE Negative Predictions: 19.33%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 66.26%
# Average Num. of 10% Confident and FALSE Predictions: 33.74%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on SEUS_Prototype7 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 61.50%
# Accuracy, Training: 63.27%
# Accuracy, Testing: 58.67%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0981
# Brier Skill Score (Test): 0.0184
# Brier Skill Score (Validation): 0.0644
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7112
# Recall Accuracy Score (Test): 0.7485
# Recall AccuracyScore (Validation): 0.7002
# Precision Accuracy Score (Train): 0.6267
# Precision Accuracy Score (Test): 0.5411
# Precision AccuracyScore (Validation): 0.6109
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5493
# Recall Accuracy Score (Test): 0.4454
# Recall AccuracyScore (Validation): 0.5239
# Precision Accuracy Score (Train): 0.6421
# Precision Accuracy Score (Test): 0.6700
# Precision AccuracyScore (Validation): 0.6219
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 31.84%
# Average Num. of 10% Confident and Correct Negative Predictions: 31.43%
# Average Num. of 10% Confident and FALSE Postive Predictions: 18.17%
# Average Num. of 10% Confident and FALSE Negative Predictions: 18.56%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 63.27%
# Average Num. of 10% Confident and FALSE Predictions: 36.73%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on SEUS_Prototype8 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 61.58%
# Accuracy, Training: 63.32%
# Accuracy, Testing: 59.96%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0982
# Brier Skill Score (Test): 0.0276
# Brier Skill Score (Validation): 0.0654
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7142
# Recall Accuracy Score (Test): 0.7566
# Recall AccuracyScore (Validation): 0.7025
# Precision Accuracy Score (Train): 0.6268
# Precision Accuracy Score (Test): 0.5631
# Precision AccuracyScore (Validation): 0.6099
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5469
# Recall Accuracy Score (Test): 0.4535
# Recall AccuracyScore (Validation): 0.5237
# Precision Accuracy Score (Train): 0.6430
# Precision Accuracy Score (Test): 0.6671
# Precision AccuracyScore (Validation): 0.6253
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 31.67%
# Average Num. of 10% Confident and Correct Negative Predictions: 30.13%
# Average Num. of 10% Confident and FALSE Postive Predictions: 18.34%
# Average Num. of 10% Confident and FALSE Negative Predictions: 19.86%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 61.80%
# Average Num. of 10% Confident and FALSE Predictions: 38.20%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
