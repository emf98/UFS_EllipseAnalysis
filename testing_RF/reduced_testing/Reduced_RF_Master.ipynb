# %% [markdown]
# ### Random Forests at 14-days leadtime for all regions.
#
# File generated 9/18/2025 for Chapter 4 of Dissertation.
# Modified 12/8/2025 for use in reduced UFS analysis.
#
# This file utilizes definition statements containing RF architecture to create three separate RF models, each for a designated forecast region.
#
# Forecast leadtime can be changed as needed.

# %%
##just to stop the excess number of warnings 
import warnings
warnings.filterwarnings('ignore')

#relevant import statements
import numpy as np
import math
import pandas as pd
import xarray as xr 
import pickle 
import matplotlib.pyplot as plt

import random
from random import seed
from random import randint
from random import sample

import seaborn as sns # statistical data visualization
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.feature_selection import SelectFromModel

import keras
import shap
# Out:
# 2025-12-08 16:51:10.019408: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-08 16:51:10.077990: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-12-08 16:51:10.078029: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-12-08 16:51:10.079120: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-12-08 16:51:10.090783: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-08 16:51:11.390929: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#import definitions 
from SkillStats_MOD import BSS, RAS, PAS

from RF_archMOD import rf_featselect,rf_90thpercentile

# %% [markdown]
# I am going to do a modified version of the architecture def here because I have to change the dataset structure.
#
# Start with bringing in the old data for training/validation.

# %%
#load OG input data, it is max/min standardized, NaNs removed
#stratospheric polar vortex ellipse diagnostics from Fernandez et al 2025 (in review)
infile = open("../old_data/nolag_extendedanom_input.p", 'rb') 
nolag_input = pickle.load(infile)
infile.close()

nolag_input.shape
# Out:
# (62, 149, 8)

# %% [markdown]
# The input data stays the same regardless of forecast region.
#
# The original array starts on October 19th. The shift send this forward to November 2nd.

# %%
idx = 135 #129 for 20, 119 for 30.
inp1 = np.empty((52,idx,7)) #cnew input array, 14 day lag. 
shift = 14

##reshaping to change lag in metrics for input
inp1[:,:,0] = nolag_input[:52,shift:,0] ##wind
inp1[:,:,1] = nolag_input[:52,shift:,1] ##ratio
inp1[:,:,2] = nolag_input[:52,shift:,2] ##latitude
inp1[:,:,3] = nolag_input[:52,shift:,3] ##longitude
inp1[:,:,4] = nolag_input[:52,shift:,4] ##size
inp1[:,:,5] = nolag_input[:52,shift:,5] ##ephi
inp1[:,:,6] = nolag_input[:52,shift:,6] ##gph

inp = inp1.reshape(52*idx,7)

#convert to pandas dataframe
input1 = pd.DataFrame(inp)
#label columns of variables for input data
col_names = ['wind','rat','cenlat','cenlon','size','ephi','gph']
input1.columns = col_names

# %%
def testing_data(p):
    infile = open(f'./new_data/input_{str(p)}.p', 'rb') 
    testing_input = pickle.load(infile)
    infile.close()
    
    inp = testing_input.reshape(56*10,7)
    
    #convert to pandas dataframe
    input2 = pd.DataFrame(inp)
    #label columns of variables for input data
    col_names = ['wind','rat','cenlat','cenlon','size','ephi','gph']
    input2.columns = col_names
    return input2

# %% [markdown]
# ### Begin RF Feature selection test.

# %%
def feat_imp_plot(important,input1,files):
    imp = np.nanmean(important, axis = 0)
    imp.shape
    
    #plot features by relative importance
    indices = np.argsort(imp)[::-1]  #sort by importance
    c = ["navy","royalblue","slateblue","blueviolet","darkviolet","purple","mediumvioletred","magenta"]
    
    plt.figure(figsize=(9, 6))
    plt.title(f'Average Feature Importances Across 100 CVs, {str(files)}',fontsize =18)
    plt.barh(range(input1.shape[1]), imp[indices], align="center", color = c)
    plt.yticks(range(input1.shape[1]), input1.columns[indices],fontsize =14)
    plt.xticks(fontsize =14)
    plt.xlabel("Relative Importance",fontsize =16)
    plt.gca().invert_yaxis()
    plt.savefig(f'./images/FeatureImportance_{str(files)}.png',bbox_inches = 'tight')

# %%
#number of cross validations
n = 100

regions = ['eur','nova','seus']

# %%
##Loop through regions and files to do feature selection.
for i in range(len(regions)):
    ##EUROPE
    if regions[i] == 'eur':
        files = ['Europe_ERA5','Europe_Prototype5','Europe_Prototype6','Europe_Prototype7','Europe_Prototype8']
        prototype = ['ERA5','Prototype5','Prototype6','Prototype7','Prototype8']
        for j in range(len(files)):
            print(f'Working on {str(files[j])} ...')
            input2 = testing_data(prototype[j])
            eur_important = rf_featselect(n,shift,idx,input1,input2,regions[i],files[j])
            feat_imp_plot(eur_important,input1,files[j])
            print('_____________________________________')
    ##CANADA
    if regions[i] == 'nova':
        files = ['Canada_ERA5','Canada_Prototype5','Canada_Prototype6','Canada_Prototype7','Canada_Prototype8']
        prototype = ['ERA5','Prototype5','Prototype6','Prototype7','Prototype8']
        for j in range(len(files)):
            print(f'Working on {str(files[j])} ...')
            input2 = testing_data(prototype[j])
            can_important = rf_featselect(n,shift,idx,input1,input2,regions[i],files[j])
            feat_imp_plot(can_important,input1,files[j])
            print('_____________________________________')
    ##SEUS
    if regions[i] == 'seus':
        files = ['SEUS_ERA5','SEUS_Prototype5','SEUS_Prototype6','SEUS_Prototype7','SEUS_Prototype8']
        prototype = ['ERA5','Prototype5','Prototype6','Prototype7','Prototype8']
        for j in range(len(files)):
            print(f'Working on {str(files[j])} ...')
            input2 = testing_data(prototype[j])
            seus_important = rf_featselect(n,shift,idx,input1,input2,regions[i],files[j])
            feat_imp_plot(seus_important,input1,files[j])
            print('_____________________________________')
# Out:
# Working on Europe_ERA5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 57.74%
# Accuracy, Training: 63.12%
# Accuracy, Testing: 62.85%
# _____________________________________
# Working on Europe_Prototype5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 57.25%
# Accuracy, Training: 63.18%
# Accuracy, Testing: 68.12%
# _____________________________________
# Working on Europe_Prototype6 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 57.33%
# Accuracy, Training: 63.21%
# Accuracy, Testing: 61.91%
# _____________________________________
# Working on Europe_Prototype7 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 57.28%
# Accuracy, Training: 63.24%
# Accuracy, Testing: 55.64%
# _____________________________________
# Working on Europe_Prototype8 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 57.21%
# Accuracy, Training: 63.22%
# Accuracy, Testing: 58.53%
# _____________________________________
# Working on Canada_ERA5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 70.49%
# Accuracy, Training: 72.12%
# Accuracy, Testing: 75.22%
# _____________________________________
# Working on Canada_Prototype5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 69.89%
# Accuracy, Training: 72.17%
# Accuracy, Testing: 68.35%
# _____________________________________
# Working on Canada_Prototype6 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 69.83%
# Accuracy, Training: 72.18%
# Accuracy, Testing: 74.26%
# _____________________________________
# Working on Canada_Prototype7 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 70.42%
# Accuracy, Training: 72.11%
# Accuracy, Testing: 71.71%
# _____________________________________
# Working on Canada_Prototype8 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 69.62%
# Accuracy, Training: 72.30%
# Accuracy, Testing: 69.00%
# _____________________________________
# Working on SEUS_ERA5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 61.14%
# Accuracy, Training: 63.22%
# Accuracy, Testing: 59.53%
# _____________________________________
# Working on SEUS_Prototype5 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 61.48%
# Accuracy, Training: 63.15%
# Accuracy, Testing: 60.62%
# _____________________________________
# Working on SEUS_Prototype6 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 61.40%
# Accuracy, Training: 63.18%
# Accuracy, Testing: 64.21%
# _____________________________________
# Working on SEUS_Prototype7 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 61.09%
# Accuracy, Training: 63.27%
# Accuracy, Testing: 60.76%
# _____________________________________
# Working on SEUS_Prototype8 ...
# Begin CV ...
# ###################################################
# Accuracy, Validation: 61.51%
# Accuracy, Training: 63.18%
# Accuracy, Testing: 55.63%
# _____________________________________

# %% [markdown]
# ## Second RF run post feature selection

# %% [markdown]
# ### Europe

# %%
##Loop through regions and files to do feature selection.
prototype = ['ERA5','Prototype5','Prototype6','Prototype7','Prototype8']
####################
files = ['Europe_ERA5','Europe_Prototype5','Europe_Prototype6','Europe_Prototype7','Europe_Prototype8']

for j in range(len(files)):
    print(f'Working on {str(files[j])} ...')
    ##select prototype testing data ...
    input2 = testing_data(prototype[j])
    
    eur_input1 = input1[["wind","cenlon","cenlat","gph"]]
    eur_input2 = input2[["wind","cenlon","cenlat","gph"]]
  
    ##CONSTANT ERA5 OUTPUT
    infile = open(f'./new_data/2classtemps_Europe_ERA5.p',"rb",)
    ERA5_temp = pickle.load(infile) 
    infile.close()

    eur_test90, eur_fulltest, eur_shap_obj, eur_posXtest, eur_FposXtest, eur_negXtest, eur_FnegXtest, acc_reg2_test, acc_reg3_test, acc_reg4_test = rf_90thpercentile(n,shift, idx, eur_input1, eur_input2, ERA5_temp, 'eur', files[j])
    #____________________________________________________#
    #plot SHAP
    plt.title(f'SHAP Values for Negative Europe Temp Anomalies, {str(files[j])}',fontsize =14, y = 1.05)
    ax = shap.plots.beeswarm(eur_shap_obj[:,:,0], show = False) ##for negative classifications ... this is physically consistent!
    plt.tight_layout()
    plt.savefig(f'./images/SHAP_{str(files[j])}.png')
    plt.close()
    #____________________________________________________#
    #plot ACC
    bins = np.linspace(0.4, 1,13)  # 10 bins from 0.4 to 1
    ##bin the testing 90th percentile accuracy data
    counts90, edges90 = np.histogram(eur_test90, bins=bins)
    countsfull, edgesfull = np.histogram(eur_fulltest, bins=bins)
    counts_era5, edges_era5= np.histogram(acc_reg3_test, bins=bins) ##relative to ERA5 truth
    #plot the full dataset
    #offset = 0.02  # Adjust this value if needed for better visibility
    plt.bar(edgesfull[:-1], countsfull, width=np.diff(edgesfull), 
            edgecolor='black', alpha=0.5, label='All Predictions', align='edge', color='blue')
    
    #plot the 90th percentile
    plt.bar(edges90[:-1], counts90, width=np.diff(edges90), 
            edgecolor='black', alpha=0.5, label='>90th Percentile Predictions', align='edge', color = 'lightblue')
    
    #plot the ERA-5 comparison
    plt.bar(edges_era5[:-1], counts_era5, width=np.diff(edges_era5), 
            edgecolor='black', alpha=0.5, label='Predictions vs. ERA-5 Truth', align='edge', color = 'indigo')
    
    plt.xlabel('Accuracy',fontsize =14)
    plt.ylabel('Number of Models',fontsize =14)
    plt.legend()
    plt.title(f'Testing ACCs for 100 CVs, {str(files[j])}',fontsize =12)
    plt.tight_layout()
    plt.savefig(f'./images/ACC_{str(files[j])}.png')
    plt.close()
    print('_____________________________________')
    #____________________________________________________#
    ##export out files to make the next few plots w/o normalization
    pickle.dump(eur_posXtest, open(f'./index/pos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FposXtest, open(f'./index/Fpos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_negXtest, open(f'./index/neg_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FnegXtest, open(f'./index/Fneg_{str(files[j])}.p', 'wb'))
# Out:
# Working on Europe_ERA5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 57.27%
# Accuracy, Training: 62.11%
# Accuracy, Testing: 61.32%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0721
# Brier Skill Score (Test): 0.0564
# Brier Skill Score (Validation): 0.0187
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7560
# Recall Accuracy Score (Test): 0.7454
# Recall AccuracyScore (Validation): 0.7169
# Precision Accuracy Score (Train): 0.6103
# Precision Accuracy Score (Test): 0.5850
# Precision AccuracyScore (Validation): 0.5691
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.4744
# Recall Accuracy Score (Test): 0.4857
# Recall AccuracyScore (Validation): 0.4203
# Precision Accuracy Score (Train): 0.6423
# Precision Accuracy Score (Test): 0.6672
# Precision AccuracyScore (Validation): 0.5843
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 42.51%
# Average Num. of 10% Confident and Correct Negative Predictions: 25.87%
# Average Num. of 10% Confident and FALSE Postive Predictions: 7.43%
# Average Num. of 10% Confident and FALSE Negative Predictions: 24.19%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 68.38%
# Average Num. of 10% Confident and FALSE Predictions: 31.62%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Europe_Prototype5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 57.56%
# Accuracy, Training: 61.93%
# Accuracy, Testing: 65.84%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0713
# Brier Skill Score (Test): 0.0946
# Brier Skill Score (Validation): 0.0199
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7471
# Recall Accuracy Score (Test): 0.8602
# Recall AccuracyScore (Validation): 0.7108
# Precision Accuracy Score (Train): 0.6100
# Precision Accuracy Score (Test): 0.5897
# Precision AccuracyScore (Validation): 0.5735
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.4803
# Recall Accuracy Score (Test): 0.4871
# Recall AccuracyScore (Validation): 0.4324
# Precision Accuracy Score (Train): 0.6373
# Precision Accuracy Score (Test): 0.8084
# Precision AccuracyScore (Validation): 0.5824
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 48.15%
# Average Num. of 10% Confident and Correct Negative Predictions: 34.08%
# Average Num. of 10% Confident and FALSE Postive Predictions: 1.86%
# Average Num. of 10% Confident and FALSE Negative Predictions: 15.91%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 82.23%
# Average Num. of 10% Confident and FALSE Predictions: 17.77%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Europe_Prototype6 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 57.63%
# Accuracy, Training: 62.03%
# Accuracy, Testing: 59.98%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0710
# Brier Skill Score (Test): 0.0603
# Brier Skill Score (Validation): 0.0217
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7524
# Recall Accuracy Score (Test): 0.7817
# Recall AccuracyScore (Validation): 0.7193
# Precision Accuracy Score (Train): 0.6101
# Precision Accuracy Score (Test): 0.5583
# Precision AccuracyScore (Validation): 0.5720
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.4765
# Recall Accuracy Score (Test): 0.4339
# Recall AccuracyScore (Validation): 0.4252
# Precision Accuracy Score (Train): 0.6400
# Precision Accuracy Score (Test): 0.6908
# Precision AccuracyScore (Validation): 0.5894
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 44.09%
# Average Num. of 10% Confident and Correct Negative Predictions: 32.37%
# Average Num. of 10% Confident and FALSE Postive Predictions: 5.89%
# Average Num. of 10% Confident and FALSE Negative Predictions: 17.65%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 76.46%
# Average Num. of 10% Confident and FALSE Predictions: 23.54%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Europe_Prototype7 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 58.42%
# Accuracy, Training: 61.88%
# Accuracy, Testing: 54.45%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0696
# Brier Skill Score (Test): -0.0092
# Brier Skill Score (Validation): 0.0287
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7532
# Recall Accuracy Score (Test): 0.7054
# Recall AccuracyScore (Validation): 0.7361
# Precision Accuracy Score (Train): 0.6082
# Precision Accuracy Score (Test): 0.5240
# Precision AccuracyScore (Validation): 0.5786
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.4727
# Recall Accuracy Score (Test): 0.3925
# Recall AccuracyScore (Validation): 0.4228
# Precision Accuracy Score (Train): 0.6393
# Precision Accuracy Score (Test): 0.5850
# Precision AccuracyScore (Validation): 0.6004
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 34.19%
# Average Num. of 10% Confident and Correct Negative Predictions: 27.16%
# Average Num. of 10% Confident and FALSE Postive Predictions: 15.78%
# Average Num. of 10% Confident and FALSE Negative Predictions: 22.86%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 61.36%
# Average Num. of 10% Confident and FALSE Predictions: 38.64%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Europe_Prototype8 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 58.05%
# Accuracy, Training: 62.02%
# Accuracy, Testing: 60.30%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0706
# Brier Skill Score (Test): 0.0402
# Brier Skill Score (Validation): 0.0229
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7508
# Recall Accuracy Score (Test): 0.7486
# Recall AccuracyScore (Validation): 0.7236
# Precision Accuracy Score (Train): 0.6103
# Precision Accuracy Score (Test): 0.5883
# Precision AccuracyScore (Validation): 0.5752
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.4778
# Recall Accuracy Score (Test): 0.4511
# Recall AccuracyScore (Validation): 0.4309
# Precision Accuracy Score (Train): 0.6391
# Precision Accuracy Score (Test): 0.6354
# Precision AccuracyScore (Validation): 0.5971
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 35.72%
# Average Num. of 10% Confident and Correct Negative Predictions: 28.20%
# Average Num. of 10% Confident and FALSE Postive Predictions: 14.29%
# Average Num. of 10% Confident and FALSE Negative Predictions: 21.80%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 63.92%
# Average Num. of 10% Confident and FALSE Predictions: 36.08%
#
#
# Trying SHAP ...
# Done.
# _____________________________________

# %% [markdown]
# ### Canada

# %%
##Loop through regions and files to do feature selection.
files = ['Canada_ERA5','Canada_Prototype5','Canada_Prototype6','Canada_Prototype7','Canada_Prototype8']

for j in range(len(files)):
    print(f'Working on {str(files[j])} ...')

    input2 = testing_data(prototype[j])
    eur_input1 = input1[["wind","cenlon","cenlat","gph"]]
    eur_input2 = input2[["wind","cenlon","cenlat","gph"]]

    ##CONSTANT ERA5 OUTPUT
    infile = open(f'./new_data/2classtemps_Canada_ERA5.p',"rb",)
    ERA5_temp = pickle.load(infile) 
    infile.close()
    
    eur_test90, eur_fulltest, eur_shap_obj, eur_posXtest, eur_FposXtest, eur_negXtest, eur_FnegXtest, acc_reg2_test, acc_reg3_test, acc_reg4_test = rf_90thpercentile(n,shift, idx, eur_input1, eur_input2, ERA5_temp, 'nova',files[j])
    #____________________________________________________#
    #plot SHAP
    plt.title(f'SHAP Values for Negative Canadian Temp Anomalies, {str(files[j])}',fontsize =14, y = 1.05)
    ax = shap.plots.beeswarm(eur_shap_obj[:,:,0], show = False) ##for negative classifications ... this is physically consistent!
    plt.tight_layout()
    plt.savefig(f'./images/SHAP_{str(files[j])}.png')
    plt.close()
    #____________________________________________________#
    #plot ACC
    bins = np.linspace(0.4, 1,13)  # 10 bins from 0.4 to 1
    ##bin the testing 90th percentile accuracy data
    counts90, edges90 = np.histogram(eur_test90, bins=bins)
    countsfull, edgesfull = np.histogram(eur_fulltest, bins=bins)
    counts_era5, edges_era5= np.histogram(acc_reg3_test, bins=bins) ##relative to ERA5 truth
    #plot the full dataset
    #offset = 0.02  # Adjust this value if needed for better visibility
    plt.bar(edgesfull[:-1], countsfull, width=np.diff(edgesfull), 
            edgecolor='black', alpha=0.5, label='All Predictions', align='edge', color='blue')
    
    #plot the 90th percentile
    plt.bar(edges90[:-1], counts90, width=np.diff(edges90), 
            edgecolor='black', alpha=0.5, label='>90th Percentile Predictions', align='edge', color = 'lightblue')
    
    #plot the ERA-5 comparison
    plt.bar(edges_era5[:-1], counts_era5, width=np.diff(edges_era5), 
            edgecolor='black', alpha=0.5, label='Predictions vs. ERA-5 Truth', align='edge', color = 'indigo')
    
    plt.xlabel('Accuracy',fontsize =14)
    plt.ylabel('Number of Models',fontsize =14)
    plt.legend()
    plt.title(f'Testing ACCs for 100 CVs, {str(files[j])}',fontsize =12)
    plt.tight_layout()
    plt.savefig(f'./images/ACC_{str(files[j])}.png')
    plt.close()
    print('_____________________________________')
    #____________________________________________________#
    ##export out files to make the next few plots w/o normalization
    pickle.dump(eur_posXtest, open(f'./index/pos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FposXtest, open(f'./index/Fpos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_negXtest, open(f'./index/neg_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FnegXtest, open(f'./index/Fneg_{str(files[j])}.p', 'wb'))
# Out:
# Working on Canada_ERA5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 70.32%
# Accuracy, Training: 71.97%
# Accuracy, Testing: 77.01%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.2194
# Brier Skill Score (Test): 0.2206
# Brier Skill Score (Validation): 0.1778
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.8762
# Recall Accuracy Score (Test): 0.8978
# Recall AccuracyScore (Validation): 0.8665
# Precision Accuracy Score (Train): 0.7044
# Precision Accuracy Score (Test): 0.7625
# Precision AccuracyScore (Validation): 0.6957
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5120
# Recall Accuracy Score (Test): 0.5772
# Recall AccuracyScore (Validation): 0.4818
# Precision Accuracy Score (Train): 0.7572
# Precision Accuracy Score (Test): 0.7906
# Precision AccuracyScore (Validation): 0.7253
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 44.66%
# Average Num. of 10% Confident and Correct Negative Predictions: 32.54%
# Average Num. of 10% Confident and FALSE Postive Predictions: 5.34%
# Average Num. of 10% Confident and FALSE Negative Predictions: 17.46%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 77.20%
# Average Num. of 10% Confident and FALSE Predictions: 22.80%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Canada_Prototype5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 69.99%
# Accuracy, Training: 72.02%
# Accuracy, Testing: 70.35%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.2206
# Brier Skill Score (Test): 0.1677
# Brier Skill Score (Validation): 0.1729
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.8757
# Recall Accuracy Score (Test): 0.9304
# Recall AccuracyScore (Validation): 0.8605
# Precision Accuracy Score (Train): 0.7052
# Precision Accuracy Score (Test): 0.6382
# Precision AccuracyScore (Validation): 0.6935
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5136
# Recall Accuracy Score (Test): 0.4798
# Recall AccuracyScore (Validation): 0.4829
# Precision Accuracy Score (Train): 0.7569
# Precision Accuracy Score (Test): 0.8777
# Precision AccuracyScore (Validation): 0.7179
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 46.45%
# Average Num. of 10% Confident and Correct Negative Predictions: 35.81%
# Average Num. of 10% Confident and FALSE Postive Predictions: 3.57%
# Average Num. of 10% Confident and FALSE Negative Predictions: 14.16%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 82.27%
# Average Num. of 10% Confident and FALSE Predictions: 17.73%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Canada_Prototype6 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 70.53%
# Accuracy, Training: 71.89%
# Accuracy, Testing: 75.92%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.2179
# Brier Skill Score (Test): 0.2384
# Brier Skill Score (Validation): 0.1838
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.8758
# Recall Accuracy Score (Test): 0.9441
# Recall AccuracyScore (Validation): 0.8653
# Precision Accuracy Score (Train): 0.7038
# Precision Accuracy Score (Test): 0.7152
# Precision AccuracyScore (Validation): 0.6975
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5105
# Recall Accuracy Score (Test): 0.5267
# Recall AccuracyScore (Validation): 0.4889
# Precision Accuracy Score (Train): 0.7560
# Precision Accuracy Score (Test): 0.8845
# Precision AccuracyScore (Validation): 0.7271
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 48.25%
# Average Num. of 10% Confident and Correct Negative Predictions: 41.64%
# Average Num. of 10% Confident and FALSE Postive Predictions: 1.79%
# Average Num. of 10% Confident and FALSE Negative Predictions: 8.32%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 89.89%
# Average Num. of 10% Confident and FALSE Predictions: 10.11%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Canada_Prototype7 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 70.43%
# Accuracy, Training: 71.96%
# Accuracy, Testing: 72.91%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.2198
# Brier Skill Score (Test): 0.1977
# Brier Skill Score (Validation): 0.1791
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.8759
# Recall Accuracy Score (Test): 0.9552
# Recall AccuracyScore (Validation): 0.8631
# Precision Accuracy Score (Train): 0.7045
# Precision Accuracy Score (Test): 0.6589
# Precision AccuracyScore (Validation): 0.6974
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5123
# Recall Accuracy Score (Test): 0.5014
# Recall AccuracyScore (Validation): 0.4882
# Precision Accuracy Score (Train): 0.7568
# Precision Accuracy Score (Test): 0.9195
# Precision AccuracyScore (Validation): 0.7234
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 48.18%
# Average Num. of 10% Confident and Correct Negative Predictions: 41.66%
# Average Num. of 10% Confident and FALSE Postive Predictions: 1.78%
# Average Num. of 10% Confident and FALSE Negative Predictions: 8.38%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 89.84%
# Average Num. of 10% Confident and FALSE Predictions: 10.16%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on Canada_Prototype8 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 69.88%
# Accuracy, Training: 72.06%
# Accuracy, Testing: 68.58%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.2213
# Brier Skill Score (Test): 0.1849
# Brier Skill Score (Validation): 0.1710
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.8755
# Recall Accuracy Score (Test): 0.8761
# Recall AccuracyScore (Validation): 0.8599
# Precision Accuracy Score (Train): 0.7058
# Precision Accuracy Score (Test): 0.6498
# Precision AccuracyScore (Validation): 0.6923
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5147
# Recall Accuracy Score (Test): 0.4740
# Recall AccuracyScore (Validation): 0.4817
# Precision Accuracy Score (Train): 0.7568
# Precision Accuracy Score (Test): 0.7765
# Precision AccuracyScore (Validation): 0.7172
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 47.36%
# Average Num. of 10% Confident and Correct Negative Predictions: 44.31%
# Average Num. of 10% Confident and FALSE Postive Predictions: 2.64%
# Average Num. of 10% Confident and FALSE Negative Predictions: 5.68%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 91.68%
# Average Num. of 10% Confident and FALSE Predictions: 8.32%
#
#
# Trying SHAP ...
# Done.
# _____________________________________

# %% [markdown]
# ### SEUS

# %%
##Loop through regions and files to do feature selection.
files = ['SEUS_ERA5','SEUS_Prototype5','SEUS_Prototype6','SEUS_Prototype7','SEUS_Prototype8']

for j in range(len(files)):
    print(f'Working on {str(files[j])} ...')
    
    input2 = testing_data(prototype[j])
    eur_input1 = input1[["wind","size","cenlat","gph"]]
    eur_input2 = input2[["wind","size","cenlat","gph"]]

    ##CONSTANT ERA5 OUTPUT
    infile = open(f'./new_data/2classtemps_SEUS_ERA5.p',"rb",)
    ERA5_temp = pickle.load(infile) 
    infile.close()
    
    eur_test90, eur_fulltest, eur_shap_obj, eur_posXtest, eur_FposXtest, eur_negXtest, eur_FnegXtest, acc_reg2_test, acc_reg3_test, acc_reg4_test = rf_90thpercentile(n,shift, idx, eur_input1, eur_input2, ERA5_temp, 'seus', files[j])
    #____________________________________________________#
    #plot SHAP
    plt.title(f'SHAP Values for SEUS Temp Anomalies, {str(files[j])}',fontsize =14, y = 1.05)
    ax = shap.plots.beeswarm(eur_shap_obj[:,:,0], show = False) ##for negative classifications ... this is physically consistent!
    plt.tight_layout()
    plt.savefig(f'./images/SHAP_{str(files[j])}.png')
    plt.close()
    #____________________________________________________#
    #plot ACC
    bins = np.linspace(0.4, 1,13)  # 10 bins from 0.4 to 1
    ##bin the testing 90th percentile accuracy data
    counts90, edges90 = np.histogram(eur_test90, bins=bins)
    countsfull, edgesfull = np.histogram(eur_fulltest, bins=bins)
    counts_era5, edges_era5= np.histogram(acc_reg3_test, bins=bins) ##relative to ERA5 truth
    #plot the full dataset
    #offset = 0.02  # Adjust this value if needed for better visibility
    plt.bar(edgesfull[:-1], countsfull, width=np.diff(edgesfull), 
            edgecolor='black', alpha=0.5, label='All Predictions', align='edge', color='blue')
    
    #plot the 90th percentile
    plt.bar(edges90[:-1], counts90, width=np.diff(edges90), 
            edgecolor='black', alpha=0.5, label='>90th Percentile Predictions', align='edge', color = 'lightblue')
    
    #plot the ERA-5 comparison
    plt.bar(edges_era5[:-1], counts_era5, width=np.diff(edges_era5), 
            edgecolor='black', alpha=0.5, label='Predictions vs. ERA-5 Truth', align='edge', color = 'indigo')
    
    plt.xlabel('Accuracy',fontsize =14)
    plt.ylabel('Number of Models',fontsize =14)
    plt.legend()
    plt.title(f'Testing ACCs for 100 CVs, {str(files[j])}',fontsize =12)
    plt.tight_layout()
    plt.savefig(f'./images/ACC_{str(files[j])}.png')
    plt.close()
    print('_____________________________________')
    #____________________________________________________#
     ##export out files to make the next few plots w/o normalization
    pickle.dump(eur_posXtest, open(f'./index/pos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FposXtest, open(f'./index/Fpos_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_negXtest, open(f'./index/neg_{str(files[j])}.p', 'wb'))
    pickle.dump(eur_FnegXtest, open(f'./index/Fneg_{str(files[j])}.p', 'wb'))
# Out:
# Working on SEUS_ERA5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 61.34%
# Accuracy, Training: 63.24%
# Accuracy, Testing: 63.04%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0985
# Brier Skill Score (Test): 0.0654
# Brier Skill Score (Validation): 0.0635
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7081
# Recall Accuracy Score (Test): 0.7022
# Recall AccuracyScore (Validation): 0.6958
# Precision Accuracy Score (Train): 0.6269
# Precision Accuracy Score (Test): 0.6630
# Precision AccuracyScore (Validation): 0.6111
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5520
# Recall Accuracy Score (Test): 0.5375
# Recall AccuracyScore (Validation): 0.5247
# Precision Accuracy Score (Train): 0.6412
# Precision Accuracy Score (Test): 0.5823
# Precision AccuracyScore (Validation): 0.6178
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 33.60%
# Average Num. of 10% Confident and Correct Negative Predictions: 39.56%
# Average Num. of 10% Confident and FALSE Postive Predictions: 16.39%
# Average Num. of 10% Confident and FALSE Negative Predictions: 10.45%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 73.16%
# Average Num. of 10% Confident and FALSE Predictions: 26.84%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on SEUS_Prototype5 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 61.20%
# Accuracy, Training: 63.29%
# Accuracy, Testing: 59.15%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0984
# Brier Skill Score (Test): 0.0508
# Brier Skill Score (Validation): 0.0627
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7137
# Recall Accuracy Score (Test): 0.6113
# Recall AccuracyScore (Validation): 0.6986
# Precision Accuracy Score (Train): 0.6267
# Precision Accuracy Score (Test): 0.5429
# Precision AccuracyScore (Validation): 0.6067
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5469
# Recall Accuracy Score (Test): 0.5752
# Recall AccuracyScore (Validation): 0.5202
# Precision Accuracy Score (Train): 0.6426
# Precision Accuracy Score (Test): 0.6422
# Precision AccuracyScore (Validation): 0.6209
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 36.66%
# Average Num. of 10% Confident and Correct Negative Predictions: 38.83%
# Average Num. of 10% Confident and FALSE Postive Predictions: 13.34%
# Average Num. of 10% Confident and FALSE Negative Predictions: 11.17%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 75.49%
# Average Num. of 10% Confident and FALSE Predictions: 24.51%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on SEUS_Prototype6 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 61.31%
# Accuracy, Training: 63.30%
# Accuracy, Testing: 64.63%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0985
# Brier Skill Score (Test): 0.0864
# Brier Skill Score (Validation): 0.0633
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7074
# Recall Accuracy Score (Test): 0.6489
# Recall AccuracyScore (Validation): 0.6954
# Precision Accuracy Score (Train): 0.6280
# Precision Accuracy Score (Test): 0.6474
# Precision AccuracyScore (Validation): 0.6097
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5540
# Recall Accuracy Score (Test): 0.6437
# Recall AccuracyScore (Validation): 0.5252
# Precision Accuracy Score (Train): 0.6410
# Precision Accuracy Score (Test): 0.6457
# Precision AccuracyScore (Validation): 0.6190
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 36.05%
# Average Num. of 10% Confident and Correct Negative Predictions: 29.14%
# Average Num. of 10% Confident and FALSE Postive Predictions: 13.97%
# Average Num. of 10% Confident and FALSE Negative Predictions: 20.85%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 65.18%
# Average Num. of 10% Confident and FALSE Predictions: 34.82%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on SEUS_Prototype7 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 61.19%
# Accuracy, Training: 63.32%
# Accuracy, Testing: 59.99%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0991
# Brier Skill Score (Test): 0.0318
# Brier Skill Score (Validation): 0.0612
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7182
# Recall Accuracy Score (Test): 0.5721
# Recall AccuracyScore (Validation): 0.7067
# Precision Accuracy Score (Train): 0.6253
# Precision Accuracy Score (Test): 0.5630
# Precision AccuracyScore (Validation): 0.6080
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5431
# Recall Accuracy Score (Test): 0.6236
# Recall AccuracyScore (Validation): 0.5094
# Precision Accuracy Score (Train): 0.6455
# Precision Accuracy Score (Test): 0.6325
# Precision AccuracyScore (Validation): 0.6184
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 33.94%
# Average Num. of 10% Confident and Correct Negative Predictions: 29.17%
# Average Num. of 10% Confident and FALSE Postive Predictions: 16.03%
# Average Num. of 10% Confident and FALSE Negative Predictions: 20.86%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 63.12%
# Average Num. of 10% Confident and FALSE Predictions: 36.88%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
# Working on SEUS_Prototype8 ...
#
# Creating lists ...
#
# Establishing RF hyperparams ...
#
# Begin RF CV.
#
# END CV.
#
#
# ###################################################
# Accuracy, Validation: 61.69%
# Accuracy, Training: 63.22%
# Accuracy, Testing: 54.94%
# _____________________________________________________________________
# Brier Skill Score (Train): 0.0978
# Brier Skill Score (Test): -0.0258
# Brier Skill Score (Validation): 0.0672
# _____________________________________________________________________
# Recall and Precision: Neg Cat
# #########
# Recall Accuracy Score (Train): 0.7100
# Recall Accuracy Score (Test): 0.5204
# Recall AccuracyScore (Validation): 0.7010
# Precision Accuracy Score (Train): 0.6265
# Precision Accuracy Score (Test): 0.5338
# Precision AccuracyScore (Validation): 0.6124
# _____________________________________________________________________
# Recall and Precision: Pos Cat
# #########
# Recall Accuracy Score (Train): 0.5496
# Recall Accuracy Score (Test): 0.5763
# Recall AccuracyScore (Validation): 0.5269
# Precision Accuracy Score (Train): 0.6411
# Precision Accuracy Score (Test): 0.5634
# Precision AccuracyScore (Validation): 0.6244
# _____________________________________________________________________
# Average Num. of 10% Confident and Correct Postive Predictions: 32.23%
# Average Num. of 10% Confident and Correct Negative Predictions: 26.57%
# Average Num. of 10% Confident and FALSE Postive Predictions: 17.77%
# Average Num. of 10% Confident and FALSE Negative Predictions: 23.43%
# #######################################################################
# Average Num. of 10% Confident and Correct Predictions: 58.80%
# Average Num. of 10% Confident and FALSE Predictions: 41.20%
#
#
# Trying SHAP ...
# Done.
# _____________________________________
